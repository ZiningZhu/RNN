# %% [markdown]
# ## TF.IDF and related algorithms ##
#
# - Just find the words with highest $tf * idf$ score in each review.
# - SVD the document matrix, parameterized by tf.idf scores.
# - Negative Matrix Factorization, to find the representing topics.

# %%
import tensorflow as tf
import numpy as np
import scipy
import pandas as pd
import json
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from nltk.corpus import stopwords
from time import time

# %%
city_desc = pd.read_csv("../data/hotels/data/" + "beijing" + ".csv")
for index, row in city_desc.iterrows():
    print ("index is {}, row[:,0] is {}".format(index, row[0]))
# Out:
# index is china_beijing_holiday_inn_central_plaza, row[:,0] is holiday inn central plaza
# index is china_beijing_hilton_beijing_wangfujing, row[:,0] is hilton beijing wangfujing
# index is china_beijing_hotel_g, row[:,0] is hotel g
# index is china_beijing_the_regent_beijing, row[:,0] is the regent beijing
# index is china_beijing_the_st_regis_beijing, row[:,0] is the st regis beijing
# index is china_beijing_park_plaza_beijing_wangfujing, row[:,0] is park plaza beijing wangfujing
# index is china_beijing_the_ritz_carlton_huamao_center, row[:,0] is the ritz carlton huamao center
# index is china_beijing_the_opposite_house, row[:,0] is the opposite house
# index is china_beijing_double_happiness_courtyard_hotel, row[:,0] is double happiness courtyard hotel
# index is china_beijing_intercontinental_financial_street_beijing, row[:,0] is intercontinental financial street beijing
# index is china_beijing_michael_s_house_in_beijing, row[:,0] is michael s house in beijing
# index is china_beijing_spring_garden_courtyard_hotel, row[:,0] is spring garden courtyard hotel
# index is china_beijing_grand_hyatt_beijing, row[:,0] is grand hyatt beijing
# index is china_beijing_raffles_beijing_hotel, row[:,0] is raffles beijing hotel
# index is china_beijing_courtyard_7, row[:,0] is courtyard 7
# index is china_beijing_kellys_courtyard, row[:,0] is kellys courtyard
# index is china_beijing_the_ritz_carlton_beijing_financial_street, row[:,0] is the ritz carlton beijing financial street
# index is china_beijing_templeside_deluxe_hutong_house_hotel, row[:,0] is templeside deluxe hutong house hotel
# index is china_beijing_the_peninsula_beijing, row[:,0] is the peninsula beijing
# index is china_beijing_sofitel_wanda_beijing, row[:,0] is sofitel wanda beijing
# index is china_beijing_china_world_hotel, row[:,0] is china world hotel
# index is china_beijing_legendale_hotel_beijing, row[:,0] is legendale hotel beijing
# index is china_beijing_marriott_hotel_beijing_city_wall, row[:,0] is marriott hotel beijing city wall
# index is china_beijing_intercontinental_beijing_beichen, row[:,0] is intercontinental beijing beichen
# index is china_beijing_beijing_sihe_courtyard_hotel, row[:,0] is beijing sihe courtyard hotel
# index is china_beijing_kapok_hotel, row[:,0] is kapok hotel
# index is china_beijing_bamboo_garden_hotel, row[:,0] is bamboo garden hotel
# index is china_beijing_hotel_new_otani_chang_fu_gong, row[:,0] is hotel new otani chang fu gong
# index is china_beijing_pullman_beijing_west_wanda, row[:,0] is pullman beijing west wanda
# index is china_beijing_renaissance_beijing_capital_hotel, row[:,0] is renaissance beijing capital hotel
# index is china_beijing_jw_marriott_hotel_beijing, row[:,0] is jw marriott hotel beijing
# index is china_beijing_shangri_la_hotel_beijing, row[:,0] is shangri la hotel beijing
# index is china_beijing_crowne_plaza_hotel_beijing, row[:,0] is crowne plaza hotel beijing
# index is china_beijing_the_westin_beijing_financial_street, row[:,0] is the westin beijing financial street
# index is china_beijing_hilton_beijing, row[:,0] is hilton beijing
# index is china_beijing_crowne_plaza_hotel_zhongguancun, row[:,0] is crowne plaza hotel zhongguancun
# index is china_beijing_the_emperor, row[:,0] is the emperor
# index is china_beijing_shangri_la_kerry_centre_hotel, row[:,0] is shangri la kerry centre hotel
# index is china_beijing_sunworld_hotel_beijing, row[:,0] is sunworld hotel beijing
# index is china_beijing_jade_garden_hotel, row[:,0] is jade garden hotel
# index is china_beijing_grand_hotel_beijing, row[:,0] is grand hotel beijing
# index is china_beijing_the_westin_beijing_chaoyang, row[:,0] is the westin beijing chaoyang
# index is china_beijing_orange_hotel_beijing_asia_games_village, row[:,0] is orange hotel beijing asia games village
# index is china_beijing_holiday_inn_express_beijing_temple_of_heaven, row[:,0] is holiday inn express beijing temple of heaven
# index is china_beijing_marco_polo_parkside_hotel, row[:,0] is marco polo parkside hotel
# index is china_beijing_xinhai_jinjiang_hotel, row[:,0] is xinhai jinjiang hotel
# index is china_beijing_aloft_beijing_haidian, row[:,0] is aloft beijing haidian
# index is china_beijing_hans_royal_garden_hotel, row[:,0] is hans royal garden hotel
# index is china_beijing_novotel_peace_hotel, row[:,0] is novotel peace hotel
# index is china_beijing_the_aman_at_summer_palace, row[:,0] is the aman at summer palace
# index is china_beijing_ascott_beijing, row[:,0] is ascott beijing
# index is china_beijing_prime_hotel, row[:,0] is prime hotel
# index is china_beijing_beijing_jade_international_youth_hostel, row[:,0] is beijing jade international youth hostel
# index is china_beijing_courtyard_by_marriott_beijing_northeast, row[:,0] is courtyard by marriott beijing northeast
# index is china_beijing_beijing_huang_yuan_hotel, row[:,0] is beijing huang yuan hotel
# index is china_beijing_bohao_radegast_hotel_beijing, row[:,0] is bohao radegast hotel beijing
# index is china_beijing_grand_mercure_hotel_xidan, row[:,0] is grand mercure hotel xidan
# index is china_beijing_empark_grand_hotel, row[:,0] is empark grand hotel
# index is china_beijing_days_inn_forbidden_city_beijing, row[:,0] is days inn forbidden city beijing
# index is china_beijing_jianguo_hotel_qianmen_beijing, row[:,0] is jianguo hotel qianmen beijing
# index is china_beijing_crowne_plaza_park_view_wuzhou, row[:,0] is crowne plaza park view wuzhou
# index is china_beijing_beijing_hotel, row[:,0] is beijing hotel
# index is china_beijing_doubletree_by_hilton_beijing, row[:,0] is doubletree by hilton beijing
# index is china_beijing_kempinski_hotel_beijing_lufthansa_center, row[:,0] is kempinski hotel beijing lufthansa center
# index is china_beijing_capital_hotel_beijing, row[:,0] is capital hotel beijing
# index is china_beijing_junzhan_hotel, row[:,0] is junzhan hotel
# index is china_beijing_hutong_inn_beijing_culture_hotel, row[:,0] is hutong inn beijing culture hotel
# index is china_beijing_holiday_inn_temple_of_heaven, row[:,0] is holiday inn temple of heaven
# index is china_beijing_jian_guo_hotel, row[:,0] is jian guo hotel
# index is china_beijing_hotel_cote_cour_beijing, row[:,0] is hotel cote cour beijing
# index is china_beijing_renaissance_beijing_hotel, row[:,0] is renaissance beijing hotel
# index is china_beijing_jingmingyuan_hotel, row[:,0] is jingmingyuan hotel
# index is china_beijing_yi_hai_business_hotel, row[:,0] is yi hai business hotel
# index is china_beijing_the_quomolangma_hotel_beijing_china, row[:,0] is the quomolangma hotel beijing china
# index is china_beijing_hejia_inn_beijing_anwai, row[:,0] is hejia inn beijing anwai
# index is china_beijing_marriott_executive_apartments_sandalwood, row[:,0] is marriott executive apartments sandalwood
# index is china_beijing_swissotel_beijing, row[:,0] is swissotel beijing
# index is china_beijing_traders_upper_east_hotel, row[:,0] is traders upper east hotel
# index is china_beijing_harmony_hotel, row[:,0] is harmony hotel
# index is china_beijing_citytel_inn, row[:,0] is citytel inn
# index is china_beijing_mercure_wanshang_beijing, row[:,0] is mercure wanshang beijing
# index is china_beijing_shatan_hotel, row[:,0] is shatan hotel
# index is china_beijing_yoyo_hotel, row[:,0] is yoyo hotel
# index is china_beijing_hotel_kunlun, row[:,0] is hotel kunlun
# index is china_beijing_howard_johnson_paragon, row[:,0] is howard johnson paragon
# index is china_beijing_ao_xiang_ge_hotel, row[:,0] is ao xiang ge hotel
# index is china_beijing_happy_dragon_hostel, row[:,0] is happy dragon hostel
# index is china_beijing_7_days_inn_beijing_gucheng, row[:,0] is 7 days inn beijing gucheng
# index is china_beijing_luxury_serviced_residence, row[:,0] is luxury serviced residence
# index is china_beijing_beijing_guangming_hotel, row[:,0] is beijing guangming hotel
# index is china_beijing_jinjiang_inn_beijing_yuquan_road, row[:,0] is jinjiang inn beijing yuquan road
# index is china_beijing_beijing_century_towers, row[:,0] is beijing century towers
# index is china_beijing_autumn_garden_courtyard_hotel, row[:,0] is autumn garden courtyard hotel
# index is china_beijing_xixi_friendship_hotel, row[:,0] is xixi friendship hotel
# index is china_beijing_the_apartment_on_financial_street, row[:,0] is the apartment on financial street
# index is china_beijing_lee_garden_service_apartment_beijing, row[:,0] is lee garden service apartment beijing
# index is china_beijing_fengshan_hotspring, row[:,0] is fengshan hotspring
# index is china_beijing_hwa_apartment_hotel, row[:,0] is hwa apartment hotel
# index is china_beijing_yunheyuan_hotel, row[:,0] is yunheyuan hotel
# index is china_beijing_hanting_hotel_beijing_dongdan, row[:,0] is hanting hotel beijing dongdan
# index is china_beijing_marriott_beijing_hotel_west, row[:,0] is marriott beijing hotel west
# index is china_beijing_soluxe_sunshine_courtyard_hotel, row[:,0] is soluxe sunshine courtyard hotel
# index is china_beijing_palm_springs_beijing_marriott_executive_apartments, row[:,0] is palm springs beijing marriott executive apartments
# index is china_beijing_shindom_inn_beijing_taoranting, row[:,0] is shindom inn beijing taoranting
# index is china_beijing_home_inn_beijing_xuanwumen, row[:,0] is home inn beijing xuanwumen
# index is china_beijing_auspicious_business_hotel, row[:,0] is auspicious business hotel
# index is china_beijing_somerset_zhongguancun, row[:,0] is somerset zhongguancun
# index is china_beijing_jinjiang_inn_beijing_west_railway_station, row[:,0] is jinjiang inn beijing west railway station
# index is china_beijing_loong_palace_hotel_resort, row[:,0] is loong palace hotel resort
# index is china_beijing_guangzhou_hotel, row[:,0] is guangzhou hotel
# index is china_beijing_zhonggong_plaza, row[:,0] is zhonggong plaza
# index is china_beijing_commune_by_the_great_wall_kempinski, row[:,0] is commune by the great wall kempinski
# index is china_beijing_yinxing_hotel, row[:,0] is yinxing hotel
# index is china_beijing_park_hyatt_beijing, row[:,0] is park hyatt beijing
# index is china_beijing_beijing_tailong_plaza_hotel, row[:,0] is beijing tailong plaza hotel
# index is china_beijing_ocean_hotel, row[:,0] is ocean hotel
# index is china_beijing_jinjiang_inn_beijing_madianqiao, row[:,0] is jinjiang inn beijing madianqiao
# index is china_beijing_tianlun_dynasty_hotel, row[:,0] is tianlun dynasty hotel
# index is china_beijing_nikko_new_century_beijing_hotel, row[:,0] is nikko new century beijing hotel
# index is china_beijing_xiang_da_international_hotel, row[:,0] is xiang da international hotel
# index is china_beijing_super_8_beijingtongzhou_xinhua_street, row[:,0] is super 8 beijingtongzhou xinhua street
# index is china_beijing_ruicheng_hotel, row[:,0] is ruicheng hotel
# index is china_beijing_vienna_hotel_beijing_huayuan, row[:,0] is vienna hotel beijing huayuan
# index is china_beijing_yuyang_hotel, row[:,0] is yuyang hotel
# index is china_beijing_home_inn_beijing_beiwei_road, row[:,0] is home inn beijing beiwei road
# index is china_beijing_hua_thai_hotel, row[:,0] is hua thai hotel
# index is china_beijing_crowne_plaza_sun_palace_beijing, row[:,0] is crowne plaza sun palace beijing
# index is china_beijing_gehua_new_century_hotel, row[:,0] is gehua new century hotel
# index is china_beijing_ruyi_business_hotel_beijing, row[:,0] is ruyi business hotel beijing
# index is china_beijing_beijing_kuntai_hotel, row[:,0] is beijing kuntai hotel
# index is china_beijing_beijing_friendship_hotel_grand_building, row[:,0] is beijing friendship hotel grand building
# index is china_beijing_oakwood_residence_beijing, row[:,0] is oakwood residence beijing
# index is china_beijing_holiday_inn_beijing_lido, row[:,0] is holiday inn beijing lido
# index is china_beijing_7_days_inn_beijing_olympic_village_second, row[:,0] is 7 days inn beijing olympic village second
# index is china_beijing_grand_view_garden_hotel, row[:,0] is grand view garden hotel
# index is china_beijing_shindom_inn_beijing_guangming_bridge, row[:,0] is shindom inn beijing guangming bridge
# index is china_beijing_jinjiang_inn_beijing_xizhimen, row[:,0] is jinjiang inn beijing xizhimen
# index is china_beijing_xi_jiao_hotel_beijing, row[:,0] is xi jiao hotel beijing
# index is china_beijing_xiyuan_hotel, row[:,0] is xiyuan hotel
# index is china_beijing_jing_an_shengtang_hotel_beijing_huangchenggen, row[:,0] is jing an shengtang hotel beijing huangchenggen
# index is china_beijing_huadu_hotel, row[:,0] is huadu hotel
# index is china_beijing_holiday_inn_express_beijing_minzuyuan, row[:,0] is holiday inn express beijing minzuyuan
# index is china_beijing_hotel_ibis_beijing_sanyuan, row[:,0] is hotel ibis beijing sanyuan
# index is china_beijing_hollyear_hotel_beijing, row[:,0] is hollyear hotel beijing
# index is china_beijing_home_inn_beijing_liuliqiao, row[:,0] is home inn beijing liuliqiao
# index is china_beijing_orange_hotel_beijing_tianningsi, row[:,0] is orange hotel beijing tianningsi
# index is china_beijing_jinqiao_international_apartment_hotel, row[:,0] is jinqiao international apartment hotel
# index is china_beijing_joy_inn_beijing_hongmiao, row[:,0] is joy inn beijing hongmiao
# index is china_beijing_beijing_fragrant_hill_villa, row[:,0] is beijing fragrant hill villa
# index is china_beijing_tiantan_hotel, row[:,0] is tiantan hotel
# index is china_beijing_jinjiang_inn_beijing_jiuxianqiao, row[:,0] is jinjiang inn beijing jiuxianqiao
# index is china_beijing_hanting_express_beijing_wukesong, row[:,0] is hanting express beijing wukesong
# index is china_beijing_shindom_inn_beijing_chongwenmen, row[:,0] is shindom inn beijing chongwenmen
# index is china_beijing_oriental_bay_international_hotel, row[:,0] is oriental bay international hotel
# index is china_beijing_jili_plaza, row[:,0] is jili plaza
# index is china_beijing_hanting_express_beijing_changhongqiao, row[:,0] is hanting express beijing changhongqiao
# index is china_beijing_beijing_dabao_hotel, row[:,0] is beijing dabao hotel
# index is china_beijing_hejia_hotel_beijing_baiyun_bridge, row[:,0] is hejia hotel beijing baiyun bridge
# index is china_beijing_motel_268_beijing_wangfujing, row[:,0] is motel 268 beijing wangfujing
# index is china_beijing_jingguang_center_apartment_hotel, row[:,0] is jingguang center apartment hotel
# index is china_beijing_orange_hotel_beijing_wangjing, row[:,0] is orange hotel beijing wangjing
# index is china_beijing_a_house_apartment_hotel_bird_s_nest, row[:,0] is a house apartment hotel bird s nest
# index is china_beijing_green_tree_inn_beijing_chaoyang_north_road, row[:,0] is green tree inn beijing chaoyang north road
# index is china_beijing_yuanchenxin_international_hotel, row[:,0] is yuanchenxin international hotel
# index is china_beijing_xinyuan_inn, row[:,0] is xinyuan inn
# index is china_beijing_holiday_inn_downtown_beijing, row[:,0] is holiday inn downtown beijing
# index is china_beijing_365_inn_beijing_qianmen, row[:,0] is 365 inn beijing qianmen
# index is china_beijing_shindom_inn_headquarter, row[:,0] is shindom inn headquarter
# index is china_beijing_jiang_shan_yi_yuan_hotel, row[:,0] is jiang shan yi yuan hotel
# index is china_beijing_jingmeng_plaza, row[:,0] is jingmeng plaza
# index is china_beijing_oriental_culture_hotel, row[:,0] is oriental culture hotel
# index is china_beijing_beijing_longdinghua_hotel, row[:,0] is beijing longdinghua hotel
# index is china_beijing_7_days_inn_beijing_liujiayao, row[:,0] is 7 days inn beijing liujiayao
# index is china_beijing_golden_inn_beijing_jingsong, row[:,0] is golden inn beijing jingsong
# index is china_beijing_traders_hotel, row[:,0] is traders hotel
# index is china_beijing_wangfujing_grand_hotel, row[:,0] is wangfujing grand hotel
# index is china_beijing_tianxin_education_hotel, row[:,0] is tianxin education hotel
# index is china_beijing_huanghe_jingdu_hotel, row[:,0] is huanghe jingdu hotel
# index is china_beijing_class_fotel_hotel, row[:,0] is class fotel hotel
# index is china_beijing_tianrui_beijing, row[:,0] is tianrui beijing
# index is china_beijing_home_inn_beijing_guomao, row[:,0] is home inn beijing guomao
# index is china_beijing_gloria_plaza_hotel_beijing, row[:,0] is gloria plaza hotel beijing
# index is china_beijing_guomen_business_hotel, row[:,0] is guomen business hotel
# index is china_beijing_hanting_hotel_beijing_xuanwumen, row[:,0] is hanting hotel beijing xuanwumen
# index is china_beijing_qianyuan_international_business_hotel, row[:,0] is qianyuan international business hotel
# index is china_beijing_yong_an_hotel, row[:,0] is yong an hotel
# index is china_beijing_beijing_far_east_international_youth_hostel, row[:,0] is beijing far east international youth hostel
# index is china_beijing_orange_hotel_beijing_zhongguancun, row[:,0] is orange hotel beijing zhongguancun
# index is china_beijing_hanting_hotel_beijing_dongzhimen, row[:,0] is hanting hotel beijing dongzhimen
# index is china_beijing_dahua_jinwan_hotel, row[:,0] is dahua jinwan hotel
# index is china_beijing_crab_island_natural_resort, row[:,0] is crab island natural resort
# index is china_beijing_new_world_hotel_jing_guang, row[:,0] is new world hotel jing guang
# index is china_beijing_colour_inn_beijing_jinsheng_hongda_trading, row[:,0] is colour inn beijing jinsheng hongda trading
# index is china_beijing_zhong_an_inn_zhong_an_hotel, row[:,0] is zhong an inn zhong an hotel
# index is china_beijing_kuntai_royal_hotel, row[:,0] is kuntai royal hotel
# index is china_beijing_plaza_hotel_beijing, row[:,0] is plaza hotel beijing
# index is china_beijing_home_inn_beijing_guang_anmen, row[:,0] is home inn beijing guang anmen
# index is china_beijing_7_days_inn_beijing_huawei, row[:,0] is 7 days inn beijing huawei
# index is china_beijing_courtyard_by_marriott, row[:,0] is courtyard by marriott
# index is china_beijing_crowne_plaza_international_airport_hotel_beijing, row[:,0] is crowne plaza international airport hotel beijing
# index is china_beijing_b_b_inn_beijing_shaoyaoju, row[:,0] is b b inn beijing shaoyaoju
# index is china_beijing_peixin_hotel_beijing, row[:,0] is peixin hotel beijing
# index is china_beijing_home_inn_beijing_international_exhibition_center_san_yuan_bridge, row[:,0] is home inn beijing international exhibition center san yuan bridge
# index is china_beijing_china_people_s_palace, row[:,0] is china people s palace
# index is china_beijing_beijing_dong_fang_hotel, row[:,0] is beijing dong fang hotel
# index is china_beijing_hanting_express_beijing_bird_s_nest_olympic_stadium, row[:,0] is hanting express beijing bird s nest olympic stadium
# index is china_beijing_liangma_tianyang_hotel, row[:,0] is liangma tianyang hotel
# index is china_beijing_joy_city_hotel, row[:,0] is joy city hotel
# index is china_beijing_green_tree_inn_beijing_national_stadium, row[:,0] is green tree inn beijing national stadium
# index is china_beijing_kaide_hotel, row[:,0] is kaide hotel
# index is china_beijing_beijing_international_shipping_hotel, row[:,0] is beijing international shipping hotel
# index is china_beijing_7_days_inn_beijing_dongsi, row[:,0] is 7 days inn beijing dongsi
# index is china_beijing_tianzhao_hotel, row[:,0] is tianzhao hotel
# index is china_beijing_7_days_inn_beijing_sihui, row[:,0] is 7 days inn beijing sihui
# index is china_beijing_joy_inn_beijing_xizhimen, row[:,0] is joy inn beijing xizhimen
# index is china_beijing_qianmen_hotel, row[:,0] is qianmen hotel
# index is china_beijing_oriental_garden_hotel, row[:,0] is oriental garden hotel
# index is china_beijing_novotel_xinqiao_beijing, row[:,0] is novotel xinqiao beijing
# index is china_beijing_huanyu_jinghang_airport_hotel, row[:,0] is huanyu jinghang airport hotel
# index is china_beijing_hebei_hotel_beijing, row[:,0] is hebei hotel beijing
# index is china_beijing_beijing_coto_modern_hotel_hepingli, row[:,0] is beijing coto modern hotel hepingli
# index is china_beijing_city_hotel_beijing, row[:,0] is city hotel beijing
# index is china_beijing_jinghai_building, row[:,0] is jinghai building
# index is china_beijing_cinderella_apartments, row[:,0] is cinderella apartments
# index is china_beijing_jinheng_hotel, row[:,0] is jinheng hotel
# index is china_beijing_wendu_shortcut_business_affairs_hotel, row[:,0] is wendu shortcut business affairs hotel
# index is china_beijing_7_days_inn_beijing_madianqiao, row[:,0] is 7 days inn beijing madianqiao
# index is china_beijing_days_inn_joiest_beijing, row[:,0] is days inn joiest beijing
# index is china_beijing_beijing_international_hotel, row[:,0] is beijing international hotel
# index is china_beijing_super_8_beijing_fang_zhuang_shun_xiang, row[:,0] is super 8 beijing fang zhuang shun xiang
# index is china_beijing_comfort_suites_beijing_yayuncun, row[:,0] is comfort suites beijing yayuncun
# index is china_beijing_jinjiang_inn_beijing_tiantan_park, row[:,0] is jinjiang inn beijing tiantan park
# index is china_beijing_jingcheng_138_business_hotel, row[:,0] is jingcheng 138 business hotel
# index is china_beijing_grand_millennium_beijing, row[:,0] is grand millennium beijing
# index is china_beijing_super_8_beijing_bird_s_nest, row[:,0] is super 8 beijing bird s nest
# index is china_beijing_dingsheng_garden_hotel, row[:,0] is dingsheng garden hotel
# index is china_beijing_fujian_hotel, row[:,0] is fujian hotel
# index is china_beijing_green_tree_inn_beijing_tangren_street_one_liuli_bridge, row[:,0] is green tree inn beijing tangren street one liuli bridge
# index is china_beijing_home_inn_beijing_anzhen, row[:,0] is home inn beijing anzhen
# index is china_beijing_golden_inn_beijing_sijiqing, row[:,0] is golden inn beijing sijiqing
# index is china_beijing_holiday_inn_express_beijing_wangjing, row[:,0] is holiday inn express beijing wangjing
# index is china_beijing_beijing_broadcasting_tower_hotel, row[:,0] is beijing broadcasting tower hotel
# index is china_beijing_xisi_hotel, row[:,0] is xisi hotel
# index is china_beijing_lovetown_travel_hotel_beijing_guomao, row[:,0] is lovetown travel hotel beijing guomao
# index is china_beijing_green_tree_inn_beijing_shijin_moutain, row[:,0] is green tree inn beijing shijin moutain
# index is china_beijing_tiantian_holiday_hotel, row[:,0] is tiantian holiday hotel
# index is china_beijing_7_days_inn_beijing_jingsong, row[:,0] is 7 days inn beijing jingsong
# index is china_beijing_jialihua_guest_house_beijing_dingfuzhuang, row[:,0] is jialihua guest house beijing dingfuzhuang
# index is china_beijing_super_8_beijing_ao_yun_cun, row[:,0] is super 8 beijing ao yun cun
# index is china_beijing_harat_austraders_hotel, row[:,0] is harat austraders hotel
# index is china_beijing_hanting_hotel_beijing_wangfujing, row[:,0] is hanting hotel beijing wangfujing
# index is china_beijing_kandanhong_hotel, row[:,0] is kandanhong hotel
# index is china_beijing_holiday_inn_chang_an_west, row[:,0] is holiday inn chang an west
# index is china_beijing_jinbaili_hotel, row[:,0] is jinbaili hotel
# index is china_beijing_home_inn_beijing_yozhuang_tianhua_west_road, row[:,0] is home inn beijing yozhuang tianhua west road
# index is china_beijing_zhonguanyuan_global_village_pku, row[:,0] is zhonguanyuan global village pku
# index is china_beijing_hanting_express_beijing_zhongguancun_south, row[:,0] is hanting express beijing zhongguancun south
# index is china_beijing_guoren_hotel, row[:,0] is guoren hotel
# index is china_beijing_home_inn_beijing_cai_shi_kou, row[:,0] is home inn beijing cai shi kou
# index is china_beijing_baolinxuan_international_hotel, row[:,0] is baolinxuan international hotel

# %%
f = open("../data/hotels/data/beijing/china_beijing_tianlun_dynasty_hotel")
s = f.read()
sl = s.split('\t')
i = 0
while (i < len(sl) - 2):

    timestamp = sl[i].strip("\n")
    title = sl[i+1].strip("\n")
    review = sl[i+2].strip("\n")
    print ("{}: {}".format(i, timestamp))
    print ("--------------------------")
    print ("{}: {}".format(i+1, title))
    print ("--------------------------")
    print ("{}: {}".format(i+2, review))
    print ("--------------------------")
    i += 3
# Out:
# 0: Nov 19 2009
# --------------------------
# 1: Sunworld Dynasty Hotel - Better than expected
# --------------------------
# 2: At the last minute, we booked Sunworld Dynasty hotel through the Agoda website. We stayed for five nights and the service we received is on par with standards of a five star foreign-own hotels (e.g. Sheraton). Most staff could communicate in English, which was helpful. (Not a lot of locals in the city can speak/understand English so it was nice to be able to speak our first language at the end of the day). Complimentary bottles of water were provided every day. We had a fair size room with a king bed. Bathroom was also a nice size with a shower and a bathtub. Turn down service was a nice touch. Note that there is only one non-smoking floor. Gym and pool facilities were also very good.
# --------------------------
# 3: Oct 29 2009
# --------------------------
# 4: Crappy hotel
# --------------------------
# 5: It is now known as the Sunworld Dynasty Hotel. rated itself as 5 stars, more like 2 stars in fact.The toilet broke down in our first room and when we moved to another room, the toilet broke down again twice. By that stage, we were tired of moving so stayed put. Finally figured out that one is not supposed to dump toilet paper in the bowl. After wiping, throw it in the wastepaper basket beside the toilet bowl. I know it sounds gross but it worked.I think they have a major sewage problem in the hotel cos we saw the workmen working on the toilet in another room.Also, the ac does not work. It is always warm at 23 degrees.Go back there again,NO WAY!
# --------------------------
# 6: Oct 21 2009
# --------------------------
# 7: Ok but in need in renovation
# --------------------------
# 8: 10 years ago I stayed in this hotel for my first business trip to Beijing. It still has this impressive central hall. Apart from that, since then there has been no renovation and the management quality has detriorated. The breakfast budget still has some nice spots but also quite some room for improvement (running out of some items very early, dangerous looking sushi). Room service, even on the weekends, comes only around 3pm. Bathrooms seem to be partially redone. But still have floor standing toilets, not wall hung toilets like modern hotels have, therefore still unclean and dirty looking. Overall hotel is ok but could do better.
# --------------------------
# 9: Jan 17 2009
# --------------------------
# 10: High Quality Stay at Tianlun Dynasty
# --------------------------
# 11: Tianlun Dynasty was a great hotel with good location within walking distance to Hutongs, Tianmen Square or Wangfujing shopping street. Room was really clean, nice and spacy. Hotel had good facilities, such as massage, swimming pool and bar. Also, the breakfest buffet was excellent!
# --------------------------
# 12: Oct 16 2007
# --------------------------
# 13: Enjoyed our stay
# --------------------------
# --------------------------
# 72: Apr 22 2006
# --------------------------
# 73: Excellent Hotel......
# --------------------------
# 74: Spent 6 nights at the hotel. Great location close to restaurants, shopping and 10 min walk form TS. Hotel is well run. Room was very comfortable. The courtyard (center of the hotel) is very nice in the evening when they serve a buffet and have live classical music. The staff was very friendly and helpful. My only complaint is the breakfast buffet. It is decent but not nearly as sumptutious as I found in some less expensive hotels. I would definitely stay there again.
# --------------------------
# 75: Nov 13 2005
# --------------------------
# 76: Excellent
# --------------------------
# 77: Great hotel &amp; centrally located! Extremely pleased with my stay. Well-maintained rooms. Excellent service &amp; helpful staff. Executive floor with limited view of forbidden city &amp; complimentary continental breakfast, evening appetizers and drinks (although breakfast buffet included in rate). Very pleased with my stay. Given the bad experience I encountered with the Prime Hotel (also listed as a 4 star hotel), I could not believe the diffence in service &amp; accommodations!
# --------------------------
# 78: Nov 6 2005
# --------------------------
# 79: A good Hotel
# --------------------------
# 80: Was offered by Crowne plaza to stay in this hotel after Crowne plaza failed to open on 1/11/05. This hotel is directly oposite the Cowne plaza. Stayed for 3 nights in TianLun Dynasty. A very good hotel, excellent rooms, specially requested prior to booking, twin beded room and was given 1 large bed (5') and 1 large single (4') which was fine with us as we have 2 adults and 1 child. Their standard twin beded room is 2 no of single beds. Front desk is very helpful and efficient, Concige was strong and house keeping is very good. Plus point, in room dining is 24 hours ordered a very good Hainan chicken rice for supper. Location is very good, Macdonalds, Bakery is a short 3 minutes walk away in Tong An market complex. The hawker street is just 3 minutes walk away. Would recomend anyone to stay there. Only minus point is that there is no direct access to this hotel from Wang fu zing. you would have to walk to a side lane to enter through the main entrance.
# --------------------------
# 81: Oct 25 2005
# --------------------------
# 82: Wonderful hotel
# --------------------------
# 83: We recently stayed here for 3 nights at the beginning of our 18 day tour in China. Room was very nice with a view of the church and open courtyard next door. The inner courtyard was beautiful! We had great breakfast buffets every morning with both full Western and full Chinese choices, including an omelet/egg station. This hotel is downtown just off the main shopping area and is handy to The Forbidden City and Tiananmen Square. We would highly recommend this hotel.
# --------------------------
# 84: Sep 30 2005
# --------------------------
# 85: Excellent location
# --------------------------
# 86:
# --------------------------
# 87: Aug 31 2005
# --------------------------
# 88: Tianlun Dynasty and Beijing
# --------------------------
# 89:
# --------------------------
# 90: Aug 1 2005
# --------------------------
# 91: disappointed
# --------------------------
# 92:
# --------------------------
# 93: Jul 7 2005
# --------------------------
# 94: Great location but thats about it
# --------------------------
# 95:
# --------------------------
# 96: Jun 3 2005
# --------------------------
# 97: Great Hotel
# --------------------------
# 98:
# --------------------------
# 99: Mar 28 2005
# --------------------------
# 100: Tianlun Dynasty's 5 stars well deserved
# --------------------------
# 101:
# --------------------------
# 102: Mar 10 2005
# --------------------------
# 103: Quality Hotel
# --------------------------
# 104:
# --------------------------
# 105: Jan 8 2005
# --------------------------
# 106: nice!
# --------------------------
# 107:
# --------------------------
# 108: Nov 4 2004
# --------------------------
# 109: Highly recommend!
# --------------------------
# 110:
# --------------------------
# 111: Sep 29 2004
# --------------------------
# 112: Good night in Beijing
# --------------------------
# 113:
# --------------------------

# %%
f = open("../data/hotels/data/beijing/china_beijing_traders_hotel")
s = f.read()
sl = s.split('\t')
i = 0
while (i < len(sl) - 2):

    timestamp = sl[i].strip("\n")
    title = sl[i+1].strip("\n")
    review = sl[i+2].strip("\n")
    print ("{}: {}".format(i, timestamp))
    print ("--------------------------")
    print ("{}: {}".format(i+1, title))
    print ("--------------------------")
    print ("{}: {}".format(i+2, review))
    print ("--------------------------")
    i += 3
# Out:
# 0: Nov 13 2009
# --------------------------
# 1: Reasonable business hotel
# --------------------------
# 2: I have stayed at this hotel for about half a dozen times during the past 2 - 3 years. I have always been satisfied with them.The rooms are not large, but there's enough room for the bed and working desk. They have always been clean and perfectly functional.This time, somehow the staff at the reception was not too friendly. The staff at the concierge desk, the doormen and the elevator guards were very polite as always.The location is very good for shopping and sightseeing.This hotel is of good value for money at least with our company rate.
# --------------------------
# 3: Aug 27 2009
# --------------------------
# 4: Old weary and very overpiced... oh and badly managed!
# --------------------------
# 5: 4 years ago I checked into the Traders for what I swore would be the last time. Upon arrival they said - oh we made a mistake re your booking, please wait in the louge while we fix it... 1.5 hours later they told me they had no rooms and I would be accomodated at a nearby hotel... which turned out to be a 1 star hovel...Fast forward 4 years and through no choice I arrive at the Traders... and Im told oh sorry we have no room for you... after 40 mins they grudingly &quot;upgraded&quot; me to the &quot;top floor&quot;... The hotel is now very dated, the food ho hum and very expensive.
# --------------------------
# 6: Apr 28 2009
# --------------------------
# 7: Ah Beijing!
# --------------------------
# 8: I went with my family to Beijing last month. Incidently I booked Traders since it is very close to the shopping areas. But the rooms of this hotel are not good at all.
# --------------------------
# 9: Apr 19 2009
# --------------------------
# 10: Great for First Time Chine Business Travellers
# --------------------------
# 11: Excellent Location for a business traveller, especially if you're in China for the first time. Close to the Metro, Silk Market and other Forbidden City. Found the hotel a little expensive though
# --------------------------
# 12: Apr 16 2009
# --------------------------
# 13: Its a so-so hotel
# --------------------------
# 14: Traders Hotel in Beijing is a typical business hotel - Its located very centrally &amp; is bang next to the Guamao subway station. The hotel rooms are quite small &amp; food is average. The hotel has a spa &amp; a gym in its premises. The room rents are quite nominal for a capital city ( ~$160) - My friends who stayed at Holiday Inn Central paid half the price but said the facilities were better. Not too much of recreation like movies, games possible in the room so you are kind of bored watching only few channels on TV. The advantage of the hotel is the location &amp; a lot of places like Silk street, Tiannamen etc is close &amp; thats an advantage.
# --------------------------
# 15: Jan 14 2009
# --------------------------
# 16: OK but not worth the price
# --------------------------
# 17: Staff seems to be getting a little bit lax. Hopethey are not just trying to milk the Shangrila name andwaiting for the China World Tower to open up.Lots of better deals in Beijing now. They don't seem to get the fact that there is a global recessionand top notch service should be given to keep Golden Circle members.Time will tell.
# --------------------------
# 18: Dec 24 2008
# --------------------------
# --------------------------
# 72: Oct 19 2006
# --------------------------
# 73: business class hotel
# --------------------------
# 74: the traders is part of the shangri-la chain of well managed hotels (save for the one in shenzhen). it is better known for its convenient location. if you can tolerate a small room, this hotel would be a natural choice. what makes the traders a special hotel is its attentive english speaking front office manager, service manager-concierge, and staff.
# --------------------------
# 75: Oct 12 2006
# --------------------------
# 76: Good - but overshadowed by China World
# --------------------------
# 77: A very good hotel, but definitely living in the shadow of the China World.It was disconcerting to be regularly accosted by &quot;ladies of the night&quot; on walking between the Traders and the China World.
# --------------------------
# 78: Sep 14 2006
# --------------------------
# 79: Quiet Impressive Brekkie
# --------------------------
# 80:
# --------------------------
# 81: Jul 3 2006
# --------------------------
# 82: Businessman's hotel in a not too convenient neighborhood
# --------------------------
# 83:
# --------------------------
# 84: Apr 18 2006
# --------------------------
# 85: Hotel OK and above average
# --------------------------
# 86:
# --------------------------
# 87: Mar 22 2006
# --------------------------
# 88: A very decent hotel
# --------------------------
# 89:
# --------------------------
# 90: Dec 28 2005
# --------------------------
# 91: An very-OK 3-star hotel
# --------------------------
# 92:
# --------------------------
# 93: May 16 2005
# --------------------------
# 94: Good choice
# --------------------------
# 95:
# --------------------------
# 96: Mar 30 2005
# --------------------------
# 97: Great hotel for Beijing - good location
# --------------------------
# 98:
# --------------------------
# 99: Jan 11 2005
# --------------------------
# 100: Recommended With Minor Reservations
# --------------------------
# 101:
# --------------------------
# 102: Nov 6 2004
# --------------------------
# 103: Comfortable hotel but nothing special
# --------------------------
# 104:
# --------------------------
# 105: Sep 13 2004
# --------------------------
# 106: Excellent Business Hotel
# --------------------------
# 107:
# --------------------------
# 108: Sep 13 2004
# --------------------------
# 109: Buen Hotel
# --------------------------
# 110:
# --------------------------
# 111: Jul 3 2009
# --------------------------
# 112: ?????
# --------------------------
# 113:
# --------------------------
# 114: Apr 28 2009
# --------------------------
# 115: albergone
# --------------------------
# 116:
# --------------------------

# %%
## Process files: convert them into one file: list of comments
cities = ['beijing', 'chicago', 'dubai', 'las-vegas', 'london', 'montreal', 'new-delhi',
          'new-york-city', 'san-francisco', 'shanghai']
comments = [] # list of tuple: (timestamp, title, review)
ignored_insufficient_comment_length = 0
taken_comment = 0
FnFerror = 0
unicode_errors = 0
hotel_number = 0
total_comment = 0
for city_name in cities:
    city_desc = pd.read_csv("../data/hotels/data/" + city_name + ".csv")
    for hotel_name, _ in city_desc.iterrows():
        filename = "../data/hotels/data/{}/{}".format(city_name, hotel_name)
        hotel_number += 1
        try:
            f = open(filename, "r")
            sl = f.read()
            sl = sl.split('\t')
            i = 0
            while (i < len(sl)-2):
                total_comment += 1
                timestamp = sl[i].strip("\n")
                title = sl[i+1].strip("\n")
                review = sl[i+2].strip("\n")
                comment = (timestamp, title, review)
                i += 3
                if (len(review) < 20):
                    ignored_insufficient_comment_length += 1
                else:
                    comments.append(comment)
                    taken_comment += 1
        except (UnicodeDecodeError, FileNotFoundError) as e:
            if (e is FileNotFoundError):
                FnFerror += 1
            else:
                unicode_errors += 1
            continue
            
            
print ("Data read done! Out of {} comments from {} hotels, \
taken {}, ignored {} due to insufficient comment length, \
skipped {} due to file not found errors, and {} due to UnicodeDecodeError"
       .format(total_comment, hotel_number, taken_comment, ignored_insufficient_comment_length, FnFerror, unicode_errors))
with open("../data/comments-LoS.json", "w") as f:
    f.write(json.dumps(comments))

print ("len(comments) = {}".format(len(comments)))
print ("One comment a line:")
for i in range(5):
    print (comments[i])
# Out:
# Data read done! Out of 3513 comments from 3105 hotels, taken 3257, ignored 256 due to insufficient comment length, skipped 0 due to file not found errors, and 2827 due to UnicodeDecodeError
# len(comments) = 3257
# One comment a line:
# ('Oct 29 2009 ', 'Highly recommended - what a great place!', "On the recommendation of a friend, I stayed at Kelly's Courtyard for two nights after a business trip to Zhengzhou.The place is quiet, clean and comfortable. Comfortable rooms, great staff, a nice rooftop terrace for relaxing, and free wireless. Though a little hard to find for the uninitiated - have the Chinese address written out and ask locals if you are having trouble - it's well worth seeking out. When I return to Beijing, I will return to Kelly's Courtyard.")
# ('Oct 18 2009 ', 'Small ', "We checked in at Kelly's courtyard in the afternoon of 16 Oct. The location is a bit hard to find but once we got inside the place we felt it was worth it. This 9-rooms accommodation is tastefully decorated, quiet and really cozy. They put jazzy ambient music on all day - which is lovely. For the bedrooms, they're rather small yet they're all clean and tidy, good enough for what we paid for. What best about this place is their hospitality! The staffs, especially Jane I must say, treated us like a family rather than hotel visitors. My partner fell ill when we first arrived so later that night I had to go up to Jane, asking for some medicine. What I'm impressed is that she took this matter very seriously. We discussed for long about the symptoms, and finally Jane decided to bring me to a pharmacy nearby, helping me in every possible way to get the right medicines (for the fact that I don't speak a word of mandarin, it's such a peace of mind to have some local assist like that) So thank you Jane! I can't thank you enough. Next time we visit Beijing, I'm sure we will meet again.")
# ('Oct 17 2009 ', 'Small ', "We checked in at Kelly's courtyard in the afternoon of 16 Oct. The location is a bit hard to find but once we got inside the place we felt it was worth it. This 9-rooms accommodation is tastefully decorated, quiet and really cozy. They put jazzy ambient music on all day - which is lovely. For the bedrooms, they're rather small yet they're all clean and tidy, good enough for what we paid for. What best about this place is their hospitality! The staffs, especially Jane I must say, treated us like a family rather than hotel visitors. My partner fell ill when we first arrived so later that night I had to go up to Jane, asking for some medicine. What I'm impressed is that she took this matter very seriously. We discussed for long about the symptoms, and finally Jane decided to bring me to a pharmacy nearby, helping me in every possible way to get the right medicines (for the fact that I don't speak a word of mandarin, it's such a peace of mind to have some local assist like that) So thank you Jane! I can't thank you enough. Next time we visit Beijing, I'm sure we will meet again.Visa/Panida")
# ('Aug 27 2009', 'A relaxing stay enhanced by the attention given by the staff.', "What a wonderful introduction to Beijing. This was a memorable place to stay and how fortunate we found it. We were welcomed at 6 o'clock in the morning by Jane who was welcoming and spoke perfect English. This was followed by meeting Sandy who was equally conversant in English, he not only looked after us daily recommending various places to visit, but also booked and arranged our onward flights to Xian and Shanghai. We spent a memorable evening with Jane, Sandy and Su(who we named) learning about their way of life enjoying their company. Thanks again to you all.")
# ('Jun 25 2009 ', 'A haven of tranquility', "We stayed for a week and can only reiterate what the other reviewers have said. The helpfulness of the staff in pointing us towards the required buses and so on was a big contribution to our enjoyment of Beijing. It is a five minute walk to the main street (buses and taxis, and a subway line from Sept 2009) but that just adds to the experience. You are a bit away from the main touristy areas (thought they are easy to get to) and can get a feel for ordinary Beijing life, if that's what you want.")

# %%
# I believe some cities contain much more hotel reviews than currently read. 
# TODO - print the number of reviews read from each city!

# %%
with open("../data/comments-LoS.json") as f:
    comments = json.loads(f.read())

def reviews2vec():
    corpus = [item[2] for item in comments]
    vectorizer = TfidfVectorizer(min_df = 2)
    return vectorizer.fit_transform(corpus)
    
print ("Number of documents: {}".format(len(comments)))

A = reviews2vec()
#print ("A is {}".format(A))
# What does row and column here mean?
# M[docid, wordid] = tf.idf frequency

A
# Out:
# Number of documents: 3257
# <3257x8649 sparse matrix of type '<class 'numpy.float64'>'
# 	with 316107 stored elements in Compressed Sparse Row format>

# %%
U, S, V = scipy.sparse.linalg.svds(A, k=100)
print ("U.shape={}".format(U.shape))
print ("S.shape={}".format(S.shape))
print ("V.shape={}".format(V.shape))
# Out:
# U.shape=(3257, 500)
# S.shape=(500,)
# V.shape=(500, 8649)

# %%
# TODO - how to get topic model from SVD? Not quite obvious... Let's try LDA first.

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
with open("../data/comments-LoS.json") as f:
    comments = json.loads(f.read())
    
def LDAexample():
    corpus = [item[2] for item in comments]
    print ("Finished reading corpus! Number of reviews={}".format(len(corpus)))
    tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=1000,
                                   stop_words=stopwords.words('english'))
    print ("Start fitting tfidf transformations!")
    t0 = time()
    tf = tfidf_vectorizer.fit_transform(corpus)
    print("done in %0.3fs." % (time() - t0))
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    
    
    lda = LatentDirichletAllocation(n_topics=10, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
    print ("Start fitting LDA model!")
    t0 = time()
    lda.fit(tf)
    print("done in %0.3fs." % (time() - t0))
    
    tf_feature_names = tfidf_vectorizer.get_feature_names()
    n_top_words = 10
    print_top_words(lda, tf_feature_names, n_top_words)
    
LDAexample()
# Out:
# Finished reading corpus! Number of reviews=3257
# Start fitting tfidf transformations!
# done in 0.384s.
# Start fitting LDA model!
# done in 1.295s.
# Topic #0:
# hotel english service beijing spoke staff stay daily rooms dining
# Topic #1:
# hotel beijing star service subway room staff us everything great
# Topic #2:
# laurel beijing hotel decorated food good beautiful music courtyard walk
# Topic #3:
# hotel beijing great room pool good really spacious city spa
# Topic #4:
# hotel good beijing facilities room staff breakfast buffet great main
# Topic #5:
# ritz taxi location would hotel subway beijing town decor views
# Topic #6:
# hotel room stay good staff quot rooms great would place
# Topic #7:
# beijing hotel great highly vacation brand first good nearby well
# Topic #8:
# hotel beijing staff us room quite excellent great really wall
# Topic #9:
# hotel chinese perfect english beijing first offered quite staff everything
