# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import os
import re
import pandas as pd
# %matplotlib inline

# %%
def vocab2vec(vocab_size, vocab_length=10**7):
    f = open("Combined_String.txt", "r")
    s = f.read()
    f.close()
    D = 'abcdefghijklmnopqrstuvwxyz .,\'1234567890";'
    res = []
    for i in range(vocab_length):
        c = s[i].lower()
        v = np.zeros((vocab_size))
        try:
            idx = D.index(c)
            v[idx] = 1
            res.append(v)
        except (ValueError, IndexError) as e:
            pass
        
        
    ret = np.array(res) # A list of shape (vocab_length,) one-hot encoded characters
    print ("shape is: {}".format(ret.shape))
    return ret

#vocab2vec(40)

# %% [markdown]
# ## Gated Recurrent Unit ##
#
# - Tutorial [here](http://www.wildml.com/2015/10/recurrent-neural-network-tutorial-part-4-implementing-a-grulstm-rnn-with-python-and-theano/)
# - How the seq2seq NMT model is set up here:
#   Update gate:
#   $$z = \sigma ([x_t, C_{t-1}] W_z)$$
#   Information retain gate:
#   $$i = \sigma ([x_t, C_{t-1}] W_r)$$
#   Update cell state:
#   $$C_t = (1-z) h + z C_{t-1}$$
#   Output gate:
#   $$h = tanh ([x_r, C_{t-1}, i] W_h)$$

# %%
# My implementation of GRU on character reading - based on the equation above

class GRU:
    def __init__(self, vocab_size, cell_size, batch_size, continue_training = False, global_step = -1):
        self.batch_size = batch_size
        self.vocab_size = vocab_size
        self.cell_size = cell_size
        self.global_step = global_step
        
        self.global_step = global_step
        self.MODEL_NAME = "./model/GRU"
        self.TEST_SAMPLE_SEQ_LENGTH = 100
        self._construct_networks(vocab_size, cell_size, batch_size, continue_training, global_step)
        
        
        
    def _weight(self, shape, dtype=tf.float32, name=None):
        m = 0
        s = 1
        return tf.Variable(tf.random_normal(shape=shape, mean=m, stddev=s, dtype=dtype), dtype, name=name)
    
    def _const(self, shape, name, dtype=tf.float32):
        d0 = shape[0]
        d1 = shape[1]
        tmp = np.zeros(shape=shape)
        tmp[:, 0] = np.ones(shape=[d0, 1])
        return tf.constant(tmp, dtype=dtype, name=name)
    
    def _ohe2char(self, ohe_vec): # takes only the first row in ohe_vec
        assert ohe_vec.shape[1] == self.vocab_size
        chars = 'abcdefghijklmnopqrstuvwxyz .,\'1234567890";'
        choice_id = np.random.choice(self.vocab_size, p=ohe_vec[0,:].ravel())
        return chars[choice_id]
            
    def _clip_if_not_none(self, grad, grad_lo, grad_hi):
        if grad == None:
            return grad
        else:
            return tf.clip_by_value(grad, grad_lo, grad_hi)
        
    def _construct_networks(self, vocab_size, cell_size, batch_size, continue_training, global_step):
        graph = tf.Graph()
        with graph.as_default():
            x = tf.placeholder(tf.float32, [batch_size, vocab_size], name="x")
            y = tf.placeholder(tf.float32, [batch_size, vocab_size], name="y")
            init_C = tf.placeholder(tf.float32, [batch_size, vocab_size], name="init_C")
        
            if not continue_training:
                # Update gate
                Wz = self._weight([2 * vocab_size, cell_size], name="Wz")              
                z = tf.nn.softmax(tf.matmul(tf.concat([init_C, x], axis=1), Wz), dim=1)

                # Reset gate
                Wi = self._weight([2 * vocab_size, cell_size], name="Wi")
                i = tf.nn.softmax(tf.matmul(tf.concat([init_C, x], axis=1), Wi), dim=1)

                # Output layers
                Wo = self._weight([3 * vocab_size, vocab_size], name="Wo")
                h_ = tf.tanh(tf.matmul(tf.concat([init_C, x, i], axis=1), Wo))
                h = tf.nn.dropout(h_, keep_prob = 0.9)
                hs = tf.nn.softmax(h, dim=1)
                
                # Update cell state
                C = (1 - z) * h + z * init_C

                # Loss function, etc.
                loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=h, name="loss"))
                optimizer = tf.train.AdamOptimizer()
                grad_limit = tf.constant(5.0, dtype=tf.float32, name="grad_limit")
                grads_and_vars = optimizer.compute_gradients(loss)
                clipped_grads_and_vars = []
                for grad, var in grads_and_vars:
                    clipped_grad = self._clip_if_not_none(grad, -grad_limit, grad_limit)
                    clipped_grads_and_vars.append((clipped_grad, var))
                train_step = optimizer.apply_gradients(clipped_grads_and_vars, name="train")

                # Session, Saver, etc.
                saver = tf.train.Saver()
                sess = tf.Session()
                sess.run(tf.global_variables_initializer())
                saver.save(sess, self.MODEL_NAME,global_step=0)

            else:
                sess = tf.Session()

                saver = tf.train.import_meta_graph(self.MODEL_NAME + "-{}.meta".format(global_step))
                saver.restore(sess,tf.train.latest_checkpoint('./'))

                graph = tf.get_default_graph()

                x = graph.get_tensor_by_name("x:0")
                y = graph.get_tensor_by_name("y:0")
                init_C = graph.get_tensor_by_name("init_C:0")
                C = graph.get_tensor_by_name("C:0")
                h = graph.get_tensor_by_name("h:0")
                Wz = graph.get_tensor_by_name("Wz:0")
                Wi = graph.get_tensor_by_name("Wi:0")
               
                Wo = graph.get_tensor_by_name("Wo:0")
                loss = graph.get_tensor_by_name("loss:0")

                train_step = graph.get_tensor_by_name("train:0")
            
        
        # After creation, save to class variables
        self.x = x
        self.y = y
        self.init_C = init_C
        self.C = C
        self.h = h
        self.hs = hs
        self.loss = loss
        self.train_step = train_step
        self.saver = saver
        self.sess = sess
        
        

        
    def train(self, steps, training_data, sample = True, sample_every = 200000, save_per_step = 1000):
        save_per_steps = 10
        batch_size = self.batch_size
        vocab_size = self.vocab_size
        cell_size = self.cell_size
        
        
        for stp in range(steps):
            next_C = np.random.rand(batch_size, cell_size)
            
            p = 0
            while p < (len(training_data) - batch_size - 1):
                prev_C = next_C
                
                fdata = {self.init_C: prev_C,
                         self.x: training_data[p : p + batch_size], 
                         self.y: training_data[p+1 : p+1+batch_size]
                         }
                _, next_C, loss = self.sess.run([self.train_step, self.C, self.loss], feed_dict = fdata)
                
                p += batch_size
                
            
                if sample and p % sample_every == 0 and stp % 100 == 0:
                    # Perform a trial of sample run 
                    words_outputs = ""
                    for i in range(self.TEST_SAMPLE_SEQ_LENGTH):
                        fdata = {self.init_C: prev_C,
                                self.x: training_data[p : p + batch_size],
                                 self.y: training_data[p+1 : p+1+batch_size]
                                }
                        vec_ohe, loss = self.sess.run([self.hs, self.loss], feed_dict = fdata)
                        words_outputs += self._ohe2char(vec_ohe)
                    
                    print ("--- n = {}, p = {}, loss = {} ---".format(self.global_step+1, p, loss))
                    print ("{}\n".format(words_outputs))
                    
                    
            if self.global_step % save_per_steps == 0:
                self.saver.save(self.sess, self.MODEL_NAME, global_step = self.global_step)
        
            self.global_step += 1

# %%
if __name__ == "__main__":
    print ("Started!")
    gru = GRU(vocab_size = 40,
                    cell_size = 40,
                    batch_size = 1000,
                    continue_training = False,
                    global_step = -1)
    training_words = vocab2vec(40, 10 ** 6)-
    gru.train(steps = 10**5, training_data = training_words, sample = True, sample_every = 500000, save_per_step = 100000)
# Used 0.00001 as the standard deviation of the weights
# Out:
# Started!
# shape is: (992170, 40)
# --- n = -1, p = 500000, loss = 2.9279861450195312 ---
# qfsls rdcw62s , srtr'jaks'anscn8unb pso56dsfxi m  xtayt bib3ovv ethe 2iuc sa6epksmezhppedt.li aafkc.
#
# --- n = 99, p = 500000, loss = 2.756561517715454 ---
# otoux'q4csfts46e'tllo s1nnsocdndrohdckdc3pq0ts5,xtwnnr0 notgf sntu etd5nnfs8nop ytotwlctgs9v ougissw
#
# --- n = 199, p = 500000, loss = 2.757103204727173 ---
# tsc'nvdclgsttn2vsgpntt7sxf3ostvnd4aos tt0ptytve5rstenc mslty,gto esn've8tdttrn8 yqomc uttc s3sh5slrs
#
# --- n = 299, p = 500000, loss = 2.7569212913513184 ---
# vyc0uraqz8g ostltolns, u9gfenp21sgedctdtgsznetn4lkpnsclrwgl1tstijttzgbtstsn'ndls5ena9.tgsnetws.tnur8
#
# --- n = 399, p = 500000, loss = 2.7572059631347656 ---
# vxftcijhyhtnxwgmokl1gfbe.fkc52s3tn3oel6astizr tlg0llnscy7ytiqs05rn0xgdz8cimhecatneftlpto00v'tgclopf'
#
# --- n = 499, p = 500000, loss = 2.757526159286499 ---
# u8cs we cso nlthqsna7ae9cnzh3nm'7dazod rnet da'twccldkfv 7cgnnfasttsmnsosynfn0ossmnnonnwstn2c.tw mt'
#
# --- n = 599, p = 500000, loss = 2.757081985473633 ---
# 8onatknk smvpntvyrgfesqlvcil.s07k4w.3jty1tf2n ndnsd5d 5asznx, desetcs  t97tt ,dyntznj69ocfilep7mn ts
#
# --- n = 699, p = 500000, loss = 2.756856918334961 ---
# gms8t,thstssodg9xov68xnpgi8 nvncrnc'7qmsc yvevctcnirtmcdrsnu heoji17b8 odd5cxket.regag2 1ett,c.g0ftn
#
# --- n = 799, p = 500000, loss = 2.7562127113342285 ---
# tcteb98tz7cch,3tnnxen ssjssnf e exh10nnv mnm0t,usg6xsxngcgtcce 6hn .obz3ctntecnt9esrsinvn7innntgi tt
#
# --- n = 899, p = 500000, loss = 2.755753993988037 ---
# tg9n9niwnecac6bmstc9se8vtpwtcxsncmettn8'9cnwfttgns6odvts .s . gndc3vtnihst7uj,gs,wo20sns6c8guisqnbn
#
# --- n = 999, p = 500000, loss = 2.7552473545074463 ---
# zktc.otsdtwpco6vi'v'z3atsnltntn n,yancvdezlenh17f f2dtfjtdrttt8nu3d7nevttytqstnvrjnvveemc  ossmtrvl0
#
# --- n = 1099, p = 500000, loss = 2.7551109790802 ---
# 0nbsnpvlse'v8wsjvmsnsmt edyvldcossctsptvon'nontoiocoss6bc7decttdsnhp g3l cjs2lbvvtos5 gttr1kmtk5tmoe
#
# --- n = 1199, p = 500000, loss = 2.7549667358398438 ---
#   1 ttnn6ttn nsn50jd6fsekesrknnw8arf0c ts3luiememk,tt vn9slfcnt'cengkticqqhl  oo9tlsfl0rsnrrsuotj56u
#
# --- n = 1299, p = 500000, loss = 2.7548303604125977 ---
# oo73att cn3loodu ctsunn2cs3znn6sjerdtnscmtus ccgdco9n'bo4e  l,sc.7g5'ndltcc0ctt7tsttzsnc vxssxgn1cia
#
# --- n = 1399, p = 500000, loss = 2.7549023628234863 ---
# p4t'o lcwji90slcvamdnvfohyztct.stncnx5s,2lvlo 5et2rsydosmlt3t tcrgogktsrfslfsscl35ttbmcp.c9x'bsnreoe
#
# --- n = 1499, p = 500000, loss = 2.7548766136169434 ---
# 8sdocp tec  itaost5os5nv'92l5uonsonnttssna.vcrllzu c.rsswtxnnpsndlsgc35d5f gdumnvq.ces5srr,5dnar np.
#
# --- n = 1599, p = 500000, loss = 2.7549238204956055 ---
# 4cndcvlj  eciosses5lsee ndnt nmsettsw7c8 8tfannefedsma375wwdotscnuagiom 6g5sdlmjtneo jdtojls579hs8tn
#
# --- n = 1699, p = 500000, loss = 2.7547969818115234 ---
# 5sni7ugugdb7tt0.eccjdccrefggspiladostifds3lcuvonszndstt.wgros tttnn8t8 en ,nc5togntofgcnt9ctnntgo ss
#
# --- n = 1799, p = 500000, loss = 2.7548956871032715 ---
# 2e thos,smhmoosotttsy6  tdc0nntto 'yscnvq9.otcev,drcd 4 sw 9g6cyn tmtcmsojlt.tnnne2isl''t y54.c tdnh
#
# --- n = 1899, p = 500000, loss = 2.754831314086914 ---
# ms76oul tnznj tgvkncckosite ofespsvsnnvvln dk2 cnsknvthopdtcct5rzdsysn3lfuu dlwg 'lud da5ejsn4sifn0t
#
# --- n = 1999, p = 500000, loss = 2.7549705505371094 ---
# lut7cm4zcnof5tt0983kgcm3cl w6st ud7s9lt 617e llj2t,c, ggcnycsmcvn nxroscwlfll dnovkstzd0n93vtotttibl
#
# --- n = 2099, p = 500000, loss = 2.7549314498901367 ---
# thtvsbdoscld n 0oev nce4'vc9pslzcnn9toee0w2dffseosgienl0 .rdcidzrjdpvguh d1t0sf5t9nlnltgesncc5coc.it
#
# --- n = 2199, p = 500000, loss = 2.7549049854278564 ---
# un n2ttsss6'ivaxstdktnoktz4bvsetglross2gidttdklqt0bd mxnrorl.n4ns nsfw hlnohd78ogycnrcdcs2910seeoxmn
#
# --- n = 2299, p = 500000, loss = 2.754878044128418 ---
# oxtvqnef00yo9 ,tddsnstf et6hnegnndnttgtco h b5g7vd,nonn4vovnt9vh2'vq0 ostvdsiessshuntqebt8,jn7vn.nvn
#
# --- n = 2399, p = 500000, loss = 2.75471568107605 ---
# sndunr,1dto tcns4iwo69eoetgn0bnbfg4npngv6ajstbna kg.bcntvbtztituc8n77dot1sscovx do3s tjjcdtr lcogsfv
#
# --- n = 2499, p = 500000, loss = 2.7544193267822266 ---
# zsn 4ksswlcrtannmpe6 dc 8fcs nsemkngllkgcdtt89nca5o if't1vsn0adcdtoss2sp bggtta4dp48trf4.02bssarcv3o
#
# --- n = 2599, p = 500000, loss = 2.754535436630249 ---
# sxsmtttmishptcnofgtc3agw8v'unswzottnadh,tnvhassrn1mvq5no edqnotmttt.bquqam1oedntwtosxlonc s2l8tnovnn
#
# --- n = 2699, p = 500000, loss = 2.754425287246704 ---
# b7gasnf7ld6'hpshsujs4ottv3a.7d4zs2sannqvwnccky5s5r06bvmesgtht,tvr.vdso4gcd4jo8ms tnm01rt'teaco77sbre
#
# --- n = 2799, p = 500000, loss = 2.7543721199035645 ---
# gjvorggsnwg82stcsv6sujo5us5tpl,c'cov9rceojtv0ircycmpteciht7nxwjnon.3.lmnoosnedt zcpr37nt1cn5no59  a
#
# --- n = 2899, p = 500000, loss = 2.754333734512329 ---
# vcmtzsyswevvssttk  04sad8etc2s'o9ymgtsvr.ssdf8gnannsmvsc kogncsn5kaxgnttsnngt8'ropsgldnsgktdttemootl
#
# --- n = 2999, p = 500000, loss = 2.7541277408599854 ---
# ynt2gc07bjlxsbsdllnyrct etf4tc5.h.'zsn q c.ntnct.68n.oaancts8uxoqtlznkvon.pnsistbfsocsdznrtn4bnoef04
#
# --- n = 3099, p = 500000, loss = 2.754328489303589 ---
# n4osjttlso8tdxl.c2x5ee1zmnttt4n4sayos djrslqcs5gmo5h3cpscnssepicpssgrccc60n,nsl,svcc6f2n9tsqsl oeqt3
#
# --- n = 3199, p = 500000, loss = 2.7545931339263916 ---
# 80nlc,cs  g6nrtvtitvndcyoccmdstno7ss8h6cdmostpt ,nsb 4fsscocm54,lznvvaocscmsccjo0tqgsajfngocaul705p4
#
# --- n = 3299, p = 500000, loss = 2.7549238204956055 ---
# 4c 1v435'5ct'1snmardheg0h0'tslcdt,ccenn v5o,s270z niqexdzgwvs.rsctnnt9i2j wnttlqis0xcxr6nor 2r li bn
#
# --- n = 3399, p = 500000, loss = 2.7549021244049072 ---
# wsyq6sn8d9ze 2szn6tckes3,v'ng8tx4aflptvg8' nugtctn dn3t0z'tvznktvw0dvst.vg.n pt6ej'rnhnoszebcssreman
#
# --- n = 3499, p = 500000, loss = 2.755204439163208 ---
# 6gngz2w4vonlvxnzfogdozt  oofsc7s 'opn ne16r05t cgran s5wo1b,.bjtj8 oss5ntlsagvoybsltgmioets82to0jmc1
#
# --- n = 3599, p = 500000, loss = 2.7551093101501465 ---
# yos c68,e7ieo7tyqlqm9nn7ot6tushoejfrfsccsisn ncd  scsngs9btgh0sjv1poacclp8nttt82ogtt s8sec ol' ,,c7s
#
# --- n = 3699, p = 500000, loss = 2.7550244331359863 ---
# nnhaetcant,och2q8zs1ccs6sxdcltduth t.tocbs 'entdotnlstvss5togvgd8apgemv vleskivbnsnllnhienotisnvg y,
#
# --- n = 3799, p = 500000, loss = 2.754906177520752 ---
# s'c22tmc,dn56v2uol0s e0onvmjo,hooc, vcn4nnr6vnatnos4nnqxnyatgc. ln8tn. scdteonrncrtc6rs6dlnnsgsynv d
#
# --- n = 3899, p = 500000, loss = 2.754783868789673 ---
# un  nhn5gf23nncnt  1xodzt zqtting'tnll3t7e 0koi8d 01sckv6ct,vtu img tcztcc8f5sgg 7j c4unstnutv23s'nt
#
# --- n = 3999, p = 500000, loss = 2.7548437118530273 ---
# goswcxdtontceg,oc'cvq8ntiro7a6 mb0 vtpsm2ncdtn,uvo7fr2tlh xcyc' ss7tdlnth2lf  0ud'n5,l4db6stecftnqyj
#
# --- n = 4099, p = 500000, loss = 2.7550201416015625 ---
# vilnvlblnchdsvtsl4py5an8lccortgonnnf.n6zonsqsnphs.cntqzc0nqlsole5gcgnsfsndcsn2njtm,cenvnustt7tczg8ss
#
# --- n = 4199, p = 500000, loss = 2.7549567222595215 ---
# mrmwto2ta76jdt'w' x7ntsnltxtmpt.qas xns3'jcng46n o7la5ttazshtnrllc9rbvq2fc06yuctxmvcond3'lyel4 9nt7t
#
# --- n = 4299, p = 500000, loss = 2.7545645236968994 ---
#  t7e ml l8jmgco'2snckvgjs5ms7vkp6n egecntru ittszc2sn,vm'u vnsddlvn2nc  56qhon2dsdnlnyssjvq98dsmccnr
#
# --- n = 4399, p = 500000, loss = 2.7546732425689697 ---
# qsnsjj7ldtvjcdeyohi,sd qtlllnek0ebi,j5csc.t2nshs2 6ccvsl3s4j2nongc33enlt 8ln.sfesvn'nv3nvssns',cenzc
#
# --- n = 4499, p = 500000, loss = 2.7547497749328613 ---
# mty0er55ht7ttssa2ltnttsxtny75fctotenxt v'ccts.sstx2mv3trmstswcdf9t0nn3d4no7jocdojtde1objf rdns5csr9x
#
# --- n = 4599, p = 500000, loss = 2.7543420791625977 ---
# ber22.jntl9zsrnhncsmt4esmnt64s2t0dc sktceinv'ljldnjc kv2jt8etd 4cdndnvtg8get2  sdcysas dn'se3tgsqzr
#
# --- n = 4699, p = 500000, loss = 2.7546892166137695 ---
# n u e9bbbcdodo fcccz.ecltqv6jndnmjswesso4rn9cd4ognqz7tpon4tn intehpcnod ocsttetti10o42iv nkgntd.1jgq
#
# --- n = 4799, p = 500000, loss = 2.7546465396881104 ---
# oumssblx31s 5nd2tom c ngttrzscqczbnuve0ds,tctns zsosveowc tdvhpnsdndileonsgondntkdynn8sbvtsvq,mnecrg
#
# --- n = 4899, p = 500000, loss = 2.7546896934509277 ---
# ns dzcb9to0jtit bslzwgntnhxt 9cdcyxe3esssost v5los  jot28mfl i1e9n5s8scv5tntwotqiovrc'goqwas2xgv9d6i
#
# --- n = 4999, p = 500000, loss = 2.7549142837524414 ---
# sikvttg9,cs 9nzentetx1tslp3cdfss4 fs3cbogncosvqn'ieeistvt 61,sl41tcnn80yotn4ksgkn.ecn'estfttlurtstjd
#
# --- n = 5099, p = 500000, loss = 2.7554450035095215 ---
# 6.iscbzew'cuticze ood,vsqdvipt9dstg'dnsettsssct5pnrtesmu2ecd, sgzxnrg7sctcnedte4q5tpn'tsssnt.  b  'e
#
# --- n = 5199, p = 500000, loss = 2.755876302719116 ---
# ot6dcbs  u'idc6 bstuswnrtt'skjbqdz1gjctc6stvtctogslnvn cswntvvpy0csos j uowtalfgotrt'ro0notsn4tgh fn
#
# --- n = 5299, p = 500000, loss = 2.7566542625427246 ---
# ynnznoskumnrkow sfpco0itsvecsttsntntusg63ncfcndqstnc tmg2 oct6ntnjgnesko680uba eh8 ykers8,s1ytea47r
#
# --- n = 5399, p = 500000, loss = 2.7567293643951416 ---
# roentccymst tetcsclcttlk tmesw4t np5yvccsado2fea3gmar jctntkyssnodtt66e3ydxjngvcgsncxknnypc2sntv303y
#
# --- n = 5499, p = 500000, loss = 2.7571651935577393 ---
# 3sttdntlqsqf81. ,s 3ngmvcksn2sqt'ssocnopsrsh shade31t4v..nyptat sj2csndn6tt,2ncnn2cysse eejtn eusoe,
#
# --- n = 5599, p = 500000, loss = 2.7572526931762695 ---
# st0 poadsgs.otiys twxtmtn74 eov'.wc9 55cc9zblknwnfctd rn1acf2oacqcs rftpn,rcr7brw4sndnq9tfwcdotjtlkc
#
# --- n = 5699, p = 500000, loss = 2.757301092147827 ---
# f6d6ltg8co sbcxnktsqm vrcmntnzttna9stku07filqdcessy5cns stegssn6vov0u4nl caen0,hcsletst72ntfccai.''p
#
# --- n = 5799, p = 500000, loss = 2.757105827331543 ---
# ine83co9t2oonskng6aoet evg1mcseweeekr0r9dbnmjcmyee6 opce7ytjtvtjcnergsjruc,8nnbqhdo3sj4iihootj tautc
#
# --- n = 5899, p = 500000, loss = 2.7570502758026123 ---
# w0nfmgn cnbeso7mvs lw71nttntcfgn h,knod14 vz02nptnlgc6,tgseosytdmscenzcpvcsts axsdcgn,vctm t39tc zz.
#
# --- n = 5999, p = 500000, loss = 2.757014036178589 ---
# s8l9nnt67tdletpwtwosaqsdwtdttejvs8oodnx37djntcsvssrs cn5ecfvnvtfgeddp0 nn1bvobpg a otsx das9ndi72btt
#
# --- n = 6099, p = 500000, loss = 2.7570457458496094 ---
#  j.brccvcwwsnhcch2cbisqgvn cxi8c,rd54jz5,gmocc'51t m cfsoz4qwbnyeia,m2t1nqcrcnvl'l d5xqktzf0v utg6os
#
# --- n = 6199, p = 500000, loss = 2.7571396827697754 ---
# vtt2l'pmnmcsn,d,es1o7stkcts8xo thc,mgsywnnsv2s.dz3qyn5e1 cwhtsemtectd2enxtntnsoctyi0cvca,0cebgsln99n
#
# --- n = 6299, p = 500000, loss = 2.7571022510528564 ---
# t6ltv65cnj5x7t.vaehfcjml0os loewvsbt0ynzlmo3nvdotovny0dsst6tdccr,ckt tf4 oegdntnvrooohsayusnocism2,t
#
# --- n = 6399, p = 500000, loss = 2.7570066452026367 ---
# nswgnssnqsnj.cdcqtd5nvsnsb n'hdfsogfersyh0nnfbstos ylqve'sesss6nwn7eun89,rntveo.0no.zcn3nn nsl v,too
#
# --- n = 6499, p = 500000, loss = 2.7564430236816406 ---
# c.bv dkbsho2tld11t g n3hsfanfhsgnssfqnqe bnven8p ttt1ratssxsqg3i  nnj ecggitmyet8ag .qkzce.,ii9cppo6
#
# --- n = 6599, p = 500000, loss = 2.7566044330596924 ---
# nblcooxs,dsjeuosssvl5otk9vv7ed3a8gn2.nzzvsceklcv0l5c'1vd'tcsnsyn 2nsuke tvtruitsgn ntt8svohntnlou'yo
#
# --- n = 6699, p = 500000, loss = 2.7566354274749756 ---
# vvdcssttc2gd6nf'stxgzebvhtcftjtdtjaaqnlyosm'tndo76ve4tnswinteosh8gvg g8oferecnvv6zpstmoeocnwds1nnd7'
#
# --- n = 6799, p = 500000, loss = 2.756924629211426 ---
# os'tvfovnuctt ,241jdjvsnyj5j fv0e9lvt0tbos3s50tx8m6q,ttx8 rsre z06.sl f h1tjm1tenhsl nde sy1wan kroj
#
# --- n = 6899, p = 500000, loss = 2.7568604946136475 ---
# 392 nrvkn2nsasonnnjcctetcg ',onnlsnlvcdz4nu58xtmindon 88t v tmqlv6r8ot6stet47nttpstrepsntgmtsustte4v
#
# --- n = 6999, p = 500000, loss = 2.757171630859375 ---
# nsnsendmy ctszncosowdzxberstcvs1zcr9vz,vfl6vndtsw,tpltdnr6i2ca86vrgllxsd vdrtzcstzkw npfuk fset45kgd
#
# --- n = 7099, p = 500000, loss = 2.7572991847991943 ---
# lsconcco9cs9mq50ofjnfstrosletn rd eongmbnro r1lnnevbv42s5ed sgg xtne fbcste gte1  ns3wc13snq7m6ccna.
#
# --- n = 7199, p = 500000, loss = 2.7574987411499023 ---
# g1petlds,1zdoc,n 2tnmc5oct nnwct5joeeg 6c. 2x0,foqv8ancwsdt,3v, so4ttcnt dtvb3totvp3csjung etm uimwt
#
# --- n = 7299, p = 500000, loss = 2.7574520111083984 ---
# s75kx,de8fs'gns4s tssc'n3 sds.xwec ecmg2xv7wnatvt,klmctd,tx6snec.pfxdccnocdma'mvgtmsctn1rcs.vctendmo
#
# --- n = 7399, p = 500000, loss = 2.757368803024292 ---
# j tsgsn4ou3t0c c tzev 2r2tkacdtzs zkhcs8nsfgocl,cov4avvc6t,cnenggm,q63 tta stdtg0u3c.g6iotlmao,70p2v
#
# --- n = 7499, p = 500000, loss = 2.757363796234131 ---
# qt07el,sktnsn9ye1p7tf7dk9 9jsx7gss8s'lhiwtn6svmd5tssr25ovao58'o6crttsfnhusdojc nv2isoo 4tctdrnamd5sa
#
# --- n = 7599, p = 500000, loss = 2.757359504699707 ---
# jvz.vsantwmevtr9tvzgtsric tbswt3svei9t9gd54oz0sc0y6vg  emn14vvt56,sqsot6hd8en 3woedwcmq9fdeislmnscee
#
# --- n = 7699, p = 500000, loss = 2.7573232650756836 ---
# xntdbseced1rs0s't7 0ten8nnctn72pv4,8n87nsrtxo.citrptnocs68ckcslgxsoo2zqc.osc 5w qr6sctv4nas6m tntoms
#
# --- n = 7799, p = 500000, loss = 2.757338523864746 ---
# voqnnskcnsg'swc edttbvnt14d.trlk8ne0fehegpgsst,osetd,ihhlstk4cdct1nnnctc'4vnnnhul.m, ,2vrsvu8t7snlbc
#
# --- n = 7899, p = 500000, loss = 2.757314920425415 ---
# vlt7sls gnfgonrxtsd p3stcjssedg2 uxjgetovntteadhn,ocy,r.n4o,oetxkd5xhmcnfttn.rnsnhsrut1'lyslx0gsettc
#
# --- n = 7999, p = 500000, loss = 2.7571041584014893 ---
# qllftw.v,7f psnntsf2necc.xntwboih 8ev qvaajclonth3cwssynehuvmtxxttnls8nncutjsqs'sttts6mgksp6ttcn sra
#
# --- n = 8099, p = 500000, loss = 2.757201910018921 ---
# t9c t  6.ksts2cozkjnyn2vv5nod s sts'nnc3 ot.9nsnczr7tpaec o jceixt5ec9d7sk gn7jt nzzos0tssljr.ec.tfs
#
# --- n = 8199, p = 500000, loss = 2.7572531700134277 ---
# heoisdanoness2tnfrorllscgrsobbysm lxtn1n p gaad gnlrt tkisklb tcmcdqcf'.sttl8ncgn.ctsupx2wiepysngso0
#
# --- n = 8299, p = 500000, loss = 2.7572102546691895 ---
# cvd3scsfdo c.t,eg6mpg,ccvp fj gtnsrdklostdc,tb6n4isoftdst0f4jtesxvntfddn. tsvz3qcacoct2ynextnbk0 w t
#
# --- n = 8399, p = 500000, loss = 2.757228374481201 ---
# xn,3 eto624gmfbo 29lscstd4s8zbnovwtydeenszcpisdp0 9cszehunvtsl0o,doi'ssd7nft20tcxudmnn'ncp,6odst v4a
#
# --- n = 8499, p = 500000, loss = 2.757188081741333 ---
# cg2vuncntlmcde.cct xt6 nfr1ja 8.toncdg gaesstksvdn 84drnuebcoceotakonxnm3olx,8ro 7soncgnon9zttsoo.c3
#
# --- n = 8599, p = 500000, loss = 2.7571730613708496 ---
# cgls'1totmvwvn1efhs'i2ystnntfcr s.roe7nsirtltee c hyvnma,usptnn thhrn0n3kytcstctgmis20n mg6tdxbtv lp
#
# --- n = 8699, p = 500000, loss = 2.757235050201416 ---
# '.ngbjes4rs9d92htoocts2en emt ceooq29abldcec4ntscgrnt3ctg2spnszdi onn3lseto77n5zmgwschf0gr7wuqostr c
#
# --- n = 8799, p = 500000, loss = 2.75718092918396 ---
# ds d3yndcxe,oifrnzcxtmgnc0troo'one7gavc1ghoofs3'befty tg9n0cp5v1rlstinns7  xgf7onbni4s.cz9cnonkgcswt
#
# --- n = 8899, p = 500000, loss = 2.7571892738342285 ---
# bicnt5l 5s1djdcstdbttgn'j'lder37igswnnnfeddzsv0jinc ccs89ctmninjw4slsjfnknn ctsohscg,hep40n5no4vltds
#
# --- n = 8999, p = 500000, loss = 2.75717830657959 ---
# sntnsrhaght, ttj6ueftzuaq3hoo5ouwt 'dty 1bc f9e cgsgclsofotc8 ncqb8sv8oo so9ltctnjnckn hboignhzdunmc
#
# --- n = 9099, p = 500000, loss = 2.7569892406463623 ---
# no 5h8bn vnfuvvi4sihfwntjvpnsodvbnykcn98ocvnsnrnnsr1sflo1lotlvt6nrgfs03q60neett01txtrg,t.cw27ynont8d
#
# --- n = 9199, p = 500000, loss = 2.756870985031128 ---
# dvyidenvpsqf esvebc5dsnn.z8c  rdt5gt1nngoti.qtss4wsvjtnm8.vsgtnunnyn3 qg qgwn.t lcets4q18, tp3acgt4
#
# --- n = 9299, p = 500000, loss = 2.7567691802978516 ---
# 5 8ttc o1own.nnk ofs7ftcm c cz wf5 1 s dn.swcssynuxvctmd3n68c,cnlnrcifz2nqno7yseivvy9mkscnhgst c2gdn
#
# --- n = 9399, p = 500000, loss = 2.756809949874878 ---
# c6n aytidc  ffqs,om3ooujogs ,sv6jntst,o ,d.zctt2dxj 6'knvjfnmolsjlfic9nyn5 jsuvona nt7sg4s4g6no4po b
#
# --- n = 9499, p = 500000, loss = 2.7566444873809814 ---
# seeneyvsnt3dtn1om8ccccl9smeivy8o2dbszo7ft1c 77vtoi6nsc'bx19dtf7wj3nf0s.c svtn4b d4tsqlst8ecxsnelseev
#
# --- n = 9599, p = 500000, loss = 2.7566146850585938 ---
# tkedswongntnfs9vdtr7,7d tf gtcdx'irt5sstb7wnvtvkyngogto7'e2ocdaed4sskm5yncbwocsnqanydj6stonnsat9a0ro
#
# --- n = 9699, p = 500000, loss = 2.7564759254455566 ---
# 1xzrsnz8t aps4  qvtu 52x cydlkglrpo6n.scl celgjjxne w ftnnitstutaonnton2ccxky.kcfbg9slmme80nzcnnva'0
#
# --- n = 9799, p = 500000, loss = 2.756288528442383 ---
# 2n nf9yatbt t92wntdpntcc7g' cvfgrtd3shcusg4cqvo  iftnaf1n1tvmo usctsnftnn2stc m ccc,stdnln22sfce6sgv
#
# --- n = 9899, p = 500000, loss = 2.7563977241516113 ---
# ec 8nsnto'vxkd3r6dqb6ecl tnt 3crtjlhvccegzvndseyetosgec,tnogm uv ndtitj scdxshkskrlytannss90 6 s2e3r
#
# --- n = 9999, p = 500000, loss = 2.756657123565674 ---
# cejsstcfphd4ctdsncvr5vavv7kusin7a'srtaslcgkmlttmysoagrrlv1ccsg1jev prec1fneocgu5c eps0tmctqsf8ggrvxw
#
# --- n = 10099, p = 500000, loss = 2.756453037261963 ---
# vll ttofgv le1wsvs fetctfd  ds7qlwclortztcvcn td5etc'j,totltncsned9lggjipntid lccnsnielvdmn0jtn xszo
#
# --- n = 10199, p = 500000, loss = 2.7565972805023193 ---
# 7 osdndcsycehtc htisvs etlrfxgi1ndn8ckpgpc6blljl rnnonss tlmrn08ivtnscstvg20gc2svos2qgahn3lrtsttvgg
#
# --- n = 10299, p = 500000, loss = 2.756455898284912 ---
# gy vcvtbolstsvnc7wa1c''92ff 7lwl3ttdcv aoajjdlaozwg znun6sf6nrnecn5vl,s o8royguo ,znpdfctwgnv4ffr,f6
#
# --- n = 10399, p = 500000, loss = 2.7562389373779297 ---
# tz1ldctps'm ooraetcgggftscpgzgdlt1nfc1a.x1t42t s3 nlkf..3cnc 6hwk4jvbaovrncnneonifpwqfc1e8g cnatb29c
#
# --- n = 10499, p = 500000, loss = 2.7562761306762695 ---
# zccn.ttcry5ddlvdinnonog.3nfdg nsncqh7's.n onds7cchln5yofns6e.s3ojsqos chny sg0fzm7kidodotncz9 cbkcol
#
# --- n = 10599, p = 500000, loss = 2.7562434673309326 ---
# tcs2ydllcrx.esevhtssbz uavb9lmotatc 0lfnojzo33dqwcxtsc l5onxsvrswstgmnrekcpscu6vfnlnsecxe3'gcdldnkcn
#
# --- n = 10699, p = 500000, loss = 2.7562098503112793 ---
# g.cnelt'vlhctn67snensv1nnerr'vlsc9tcgtddcs3tvnkgsaxos'.c6n 4tdvszzsceldessvqtls3,velscnlohn cmhng nn
#
# --- n = 10799, p = 500000, loss = 2.756446599960327 ---
# 'e17v3dc mtttnoaghzeggb czna7snbsoitscsnesqdguao8dbrcedtn cdx9 t0tsnzztm0hoycop tpctscgevstegt. m3oe
#
# --- n = 10899, p = 500000, loss = 2.7564008235931396 ---
# qcsn0nsqzvzcyexc n8  5ssev2oc y,t ccds 7geot6osssnsnetc5.t3 sisc,tamj s85o4tn'1ncm1ngnks enbtjlw,ddg
#
# --- n = 10999, p = 500000, loss = 2.7562286853790283 ---
# omi6 7j8eeltlscdtqjslgoott t6wgnoxsecunnc5gevntn6rlrpdnyysotubvvsstntdutiu cvg2zi6r kvdso2n sntnr.ce
#
# --- n = 11099, p = 500000, loss = 2.75589656829834 ---
# sb c tgvdbfc9drefny'n ks5sll'wfnsnsflt6tnosrotenb.ds3abe,arnlcsptawcrctryctbctsst7h7t4t7cwjntsxoecc7
#
# --- n = 11199, p = 500000, loss = 2.7552874088287354 ---
# odtts ttar1lprsc4yodlvtk 6oshtstetmt' mlr 5sntlf2nnokekv2mvnsuedrnlnn3ksyr.k v,pldtvwtqsss2t2r24ql,e
#
# --- n = 11299, p = 500000, loss = 2.7555551528930664 ---
# ccogeuedsstrxtyminyee, olekyt3qees898sw.v,jacs446t5ynctc'sxoh9coko9't95c4xsy8ycn9n9tmt.odscyshvtc 'o
#
# --- n = 11399, p = 500000, loss = 2.7559895515441895 ---
# 3occsn  tk519gatm rmonsxcac4dn3b t57gustrsnyr8ognlhulytvcnjol8wscmsntd ta2slacsn3ggejjyqtxz2ihlhur't
#
# --- n = 11499, p = 500000, loss = 2.755770206451416 ---
# l5omc deccott nyrsvcttcen 5ixfetoh002st2nnovgnezscauatpgst8 sdswd7tvnftk36l1sbn7ontvdnfwnstsklossr7s
#
# --- n = 11599, p = 500000, loss = 2.7560620307922363 ---
# 6fty5anm,7ottcpsvlsnc0ln4ls1n 6tnkst2ohzs,h1g4ec spdq39clts8u9m dwwibeoshycpgcmsnryrbdgshf0.v9ce7r3c
#
# --- n = 11699, p = 500000, loss = 2.75624418258667 ---
# g  l7enc,udvgmahlkhvujcycsdgmlto4s5rutf sv1lnhy8znoxn2bctnsggfendoo9ttt0cv4t2e5islsetote s5hzl7v,tto
#
# --- n = 11799, p = 500000, loss = 2.7562756538391113 ---
# vojfmet5kskts5 encglcn n5ncyfsne..csjxv2co6ilhwst.xn25ccnutndyjnintn6amqnpnntzvsn 3qectbp 0m5nd0p ct
#
# --- n = 11899, p = 500000, loss = 2.756169319152832 ---
# 7 t st5dt8 8f,3dvdeoo3eh2selsihnatgttlsmf8n0es 9zot9dcg pfc1mskmt9tdj3ynn8bntua9 fhrl'o7s5 stg7vgnle
#
# --- n = 11999, p = 500000, loss = 2.7564172744750977 ---
# d0cejomtsyctd.cp cezsj0e2fd2j3fscnts33qevn1rcas .xss0srgl s9kca tsn.g5xgsnscvt t6671c.5ndy,uhbo.esom
#
# --- n = 12099, p = 500000, loss = 2.7558834552764893 ---
# st3sm't1cnvcsttekosm4h9sbgcwoibvgyndts6sntsvo imstetvdso9esscmehs t l entulemsxni k0 om v2bfzv 5ttls
#
# --- n = 12199, p = 500000, loss = 2.7559452056884766 ---
# spsnjtt5tvosxcj2xtttld2zted0ob48nrezt4.dnsttsc t7aowqsl6s.jh2t.sl3tseecctzt2ut8v8sdn'e'boanv8n5lcito
#
# --- n = 12299, p = 500000, loss = 2.7562503814697266 ---
# 509tavns niyojsp11siplscsfassos9ghylcuss cn nsvmfosoa 0n,vgshtch2dns2'0cohynscnd ctr5n '0st6negpcn'x
#
# --- n = 12399, p = 500000, loss = 2.756291151046753 ---
# 3ntgfnyi10osootnebdxcebu js cvr7cow5o4sl8zno c 6bnxodcpdnds8dtn9cstjtttvolotsnsnvm2nsc2s ur7cnk aetn
#
# --- n = 12499, p = 500000, loss = 2.756150007247925 ---
# yso.swpad16ltno4niwcun'rxmtvn5xtd ncnoos sdstnhrnn2tmaa3n22vrltsntecj1s,jwgdtnnj1vtna0lnsmn7stcputkb
#
# --- n = 12599, p = 500000, loss = 2.756051540374756 ---
# lstcycdrthns3cbi ncstgw,vtsis.ntdqccc4ggdx5tfn3sxe'tos4vcntcnvt nsn6 ftgt0lp5'isso164zsuicmnc73c51st
#
# --- n = 12699, p = 500000, loss = 2.756182909011841 ---
#  ncnncetk7o5neno0tyt.bcnromcewsueemvcdwv l tcknlcwrdssnt9ytcssanemseszze8ee  snqnvs.dln'vreegcjnn't7
#
# --- n = 12799, p = 500000, loss = 2.756131172180176 ---
# o2o yostjc0t3oo njcsxsfksuhetntq3ztsnbvldtf4rscobstrt2slnxfcjoonsc2,ssp0tie6m0tsxrcic4enscmlvdcng7nf
#
# --- n = 12899, p = 500000, loss = 2.7560479640960693 ---
# r6lydygescovhntndsbtbo5th7sft0nnolovjccnbslqergc3bstobme7l1fsw9ceisuzro'dettc'4d 5lejnasdcdghndw81r
#
# --- n = 12999, p = 500000, loss = 2.756030559539795 ---
# ssx2nnronnvotrtopcxnfnp anhn1atlnu0huookkgse0c8jcedxtw2nh cc4vsmir6608f3cntt0x vocye8d19tondsntskrio
#
# --- n = 13099, p = 500000, loss = 2.756077527999878 ---
# iicdcdtnnexntt'avl1ut mszn 1'dtcwn svt.bz4qnnqmed4mtett sloggjczsn2t ste5ttrsp6ssyn2ct nectsgxdn 8tm
#
# --- n = 13199, p = 500000, loss = 2.7563693523406982 ---
# vcnovolt3ncexfsonttqrt5572xn7omfstnsm43ccofcvt9c3ps'n6crrntcsvkq vo,cgt0 c ovc9ss6fe1je8temotpr9ydok
#
# --- n = 13299, p = 500000, loss = 2.756420135498047 ---
# wissostrt0e9tnlxh'xfdhstonsks16,.6ol4vnxteo'sndo1nsemsc8ztp4qnttt7ne9avq's2tlno5ctvht3g'd7seld ht0co
#
# --- n = 13399, p = 500000, loss = 2.7562882900238037 ---
# esdr3vzem7en.td. 'yccnvtstog tsto6do.tltsl,t efdt knsszs bnkncssctnxl1va otct1piecst rgbondsnu 4ttg
#
# --- n = 13499, p = 500000, loss = 2.7558679580688477 ---
# c0nnpnhu, oxg'vkcsnvlnwv3m b7sotr3gc3ybancckjdfccspdf9ceqolef0'fc'cvs1fgfec n1d sn,sa gnefalvsrcrtcc
#
# --- n = 13599, p = 500000, loss = 2.7559866905212402 ---
# wgtvj3qdwbzv29qvssmtc3sotz eltoeagl8nstostynst9oos.og   csqs.g9s8nsnht ttssladvqmoonac58a9sfeo'vnt5s
#
# --- n = 13699, p = 500000, loss = 2.7559237480163574 ---
# s rmsgfsnrigcrtedw7m.catedzbcts,nsccw9es4enqvp8brnzoesrb2jmmnxn m5r5s1slccotj oy5lsc0vved6tsev3oejzp
#
# --- n = 13799, p = 500000, loss = 2.7559187412261963 ---
# izenntsnpsvv'ssog,so rdsm7ce4eerj s,xcl1 jcnkgnsnacset,tcinwtcsofstnkhn1tc'homb8pcxn1en 38ovhj9.vg7g
#
# --- n = 13899, p = 500000, loss = 2.7554047107696533 ---
# nr5csn0hih5kot2tdc 8qtrndscq thneooddeyns2nnm2tr t51abto9o0dgs1tsntenslh8s5kx3ndl1ntcs, cws2djosodoc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9419d9bf68b1> in <module>()
#       7                     global_step = -1)
#       8     training_words = vocab2vec(40, 10 ** 6)
# ----> 9     gru.train(steps = 10**5, training_data = training_words, sample = True, sample_every = 500000, save_per_step = 100000)
#
# <ipython-input-4-3c509a7b6970> in train(self, steps, training_data, sample, sample_every, save_per_step)
#     136                          self.y: training_data[p+1 : p+1+batch_size]
#     137                          }
# --> 138                 _, next_C, loss = self.sess.run([self.train_step, self.C, self.loss], feed_dict = fdata)
#     139
#     140                 p += batch_size
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    print ("Started!")
    gru = GRU(vocab_size = 40,
                    cell_size = 40,
                    batch_size = 1000,
                    continue_training = False,
                    global_step = -1)
    training_words = vocab2vec(40, 10 ** 6)
    gru.train(steps = 10**5, training_data = training_words, sample = True, sample_every = 500000, save_per_step = 100000)
# Used 1 as the standard deviation of the weights
# Out:
# Started!
# shape is: (992170, 40)
# --- n = -1, p = 500000, loss = 2.9273436069488525 ---
# wq v 57gp8n34sm weao'nt coeottbgf y e ltgtcraef3dfralgfnskln  ccn3meet778qos7s9,hb8 d3nja3tt z,ztdeb
#
# --- n = 99, p = 500000, loss = 2.7560577392578125 ---
# ezven96,'id'nttt,e,yc nt. setrtr'znny7 zdtrfsnfh6lua1lgcvcnh5ov7ftjs6o 'c,'0ecd6kcunnl1 nsrsvtd  tss
#
# --- n = 199, p = 500000, loss = 2.7572073936462402 ---
# rnsc9cagc68en0sugtcv5oensn'avo9,94kgg34snttntymwenx26mcyltcjn8f'dnfkddgs yar1nl3st60dac29s,tgxlnek'c
#
# --- n = 299, p = 500000, loss = 2.7574381828308105 ---
# t5f862s eczts'rs jl oadd3enp  n88n,9cle8 svvl 8vsnmn8vtddhedfo6aue6cxvvbtjjdvzg. gsit98ssgmncj9nssss
#
# --- n = 399, p = 500000, loss = 2.7579586505889893 ---
# aonmuwdt tttdlsndgxccvscsg,t'nso7lon0cd9.stn 0c00,ylhnneg dtsnss'ndq95g no,otdct8cnntn6pv5avog.eqjzt
#
# --- n = 499, p = 500000, loss = 2.7577033042907715 ---
# vmorcpl8.1rnosovn5tsctyeesf8ttnu f.lqdcdk 3ncv8m sccmg tvdw1ystxnascom0n5ginconvnn nsllusnhn3yvwog 2
#
# --- n = 599, p = 500000, loss = 2.75646710395813 ---
#  nmdoqautfz3t7envzsoeo.s9ssgzpn2snes,5ntsnnokcnip 0ncs9c7f6dot7w5.ttfstst gg7k95d3neosstxvnldvrctreo
#
# --- n = 699, p = 500000, loss = 2.756312370300293 ---
# qt lnpv let4tnrnk3jgsa8vtstwri,ors6contoncgg n nvsycd,trdsmc o1msss5c  l dg1jnbycype 4.nocnmt4no'll5
#
# --- n = 799, p = 500000, loss = 2.7563419342041016 ---
# gn,v,ejd.sc nc'nd samd,5tfz1emoc27tnonrd1ijvendss9nnnrsdshnttifsllsj7wasusgv tnt3yodtn hpmns snndms7
#
# --- n = 899, p = 500000, loss = 2.756666421890259 ---
# tcssjfo  n12ljansupnnstsbgysnvsslxzxcusncodsb6btscs',qchcsae6 k9rc67nsxg7svrtv3frgscnc2efngdftdcvyse
#
# --- n = 999, p = 500000, loss = 2.7570738792419434 ---
# tre. dde6vvsq8 n5 c8gel6d gttclg tnjvcedt0p8c5slntt3soudcey 3mrnwec'gtr87ensvkdr4nu2t'soticfydlg ly0
#
# --- n = 1099, p = 500000, loss = 2.7566890716552734 ---
# v2ckkhst1nl bs.lvcccepmsvlsnvhnsbsotlnfnopyue7s w4ssel6m.liht tlcvvwons1 3cczuncjvmystjpsqgvct5ct ot
#
# --- n = 1199, p = 500000, loss = 2.7568535804748535 ---
# ofdwzt2tgpv4xyaen6vcfonclcstoctst8rln0ltq8netvlmvthecdkny0vk82nt,.jyntdrdtecwtis3nnc3o3cwnsacndnabqv
#
# --- n = 1299, p = 500000, loss = 2.756845712661743 ---
# dtnoo,bsgcmstgvser7lccpetx1dxto,tcyj9c or59sqn tsesol.t5fx6g,nntoj. gniltcttxr af7cssnjm89eni398s3n6
#
# --- n = 1399, p = 500000, loss = 2.756605386734009 ---
# ntvxomjndpsjnqwlt 1vsosnmgntsedavcttsbtoc0lsfy3s.ffstlc vyklttanxv.7oncltynv .airtkjvom7mntnesntq8e
#
# --- n = 1499, p = 500000, loss = 2.755876302719116 ---
# scddtwlqn3c8.lcejsctykv2ut,tcxeftglqshstvxd3ogntctrqvv95este.utt0sqly sk'torej9tb 7vs7w ccy3s64l fln
#
# --- n = 1599, p = 500000, loss = 2.756251811981201 ---
# qneenodgwtgs,'uodelvd7svtt nxst1lt0ojeegslmeat7nscttn8tmnt tcnccnnkblln6coclnahhnpnjne4o mknfteonftu
#
# --- n = 1699, p = 500000, loss = 2.756667375564575 ---
# 8xn.cqinorx scbcshzttstdzltcsssncesg8e2srlc6,snns7lmcp7s skl3wtovcs3vtncgcofuwk5th4v spmepqtdstnxefu
#
# --- n = 1799, p = 500000, loss = 2.757392168045044 ---
# ur4dsfagt8ltensouoo.l9fjfngy6loereusomce3vnztvc3vteo7c ,7dtce vqjfdy.dftqvsecdd,2 rl8vttlntckr4 sece
#
# --- n = 1899, p = 500000, loss = 2.757854700088501 ---
# gtdg7dkoggu 0ledzgl'9zcoeccntvfcwnn6nmeskossnen7oqfnlcocdosn7tsnodb8t  osmjhvyc9orn6dtent6tnbvcnncy
#
# --- n = 1999, p = 500000, loss = 2.7575976848602295 ---
# scnsateh,c5itncnx1qndeyodu996ocxljdgvsmncjnscnp96icvs45nt'8tlds'j4ooosvenk1mqyycc,nvv9od.4,ctrmetmtv
#
# --- n = 2099, p = 500000, loss = 2.757122278213501 ---
# 8scoa.on0setne t dvcrentest0n 9ueo9.xnswcyov6onnuq .e'cb eignstt4tovtccelmevic6olv5vtnstsss,n2tp6mmx
#
# --- n = 2199, p = 500000, loss = 2.7571818828582764 ---
#  tgoertmdtsvsv623'vttnnnh5o6gcossfscsttu bwdlne o1t1ct5aco u ewsdn,m3ct65sko,lh2d0pc,tg'cc.o0bwroeed
#
# --- n = 2299, p = 500000, loss = 2.7573118209838867 ---
# ttscdnnynnsgto.1ync2dhtjvoo5g25fdex3istcj3,xosbsgttnod7ctd nna xstt0cohsuhfdobencc' dss.achk0eztn,ca
#
# --- n = 2399, p = 500000, loss = 2.7578561305999756 ---
# thi,ndutc3'tstgmt eytlgjn3f ,gvnn  llh8edttcamsoccs viflctc srl nmlbntzct.s4ntosclay8cnsm d4rhvncs32
#
# --- n = 2499, p = 500000, loss = 2.7582154273986816 ---
# 2.tnftgc50cyzynsstr 4psrep.7tnlcvvsrtcareftit nnpttnod0otecns sngttcxq4jc80tns36st1t9cyegn8cd.t,svld
#
# --- n = 2599, p = 500000, loss = 2.7580795288085938 ---
# 2leclv79cn5s3cngdv  sve2 rywlv6 njfhx4c1nvwwvjt 5gnc0m4z2cszcdgastatdns0o  bt9kicoetgmzitn.wmvgsdcod
#
# --- n = 2699, p = 500000, loss = 2.7579965591430664 ---
# g7st2snhl6s 7s nnl2ntl1lcjnqsnq0hgw7yogt txt.snlc7hvxwdcuna.es0 s,ls s3gsn ovvrnth0tejomgally tsnrkn
#
# --- n = 2799, p = 500000, loss = 2.7579288482666016 ---
# mcflm8cwsoszvee9dhzs9tn9ngsss1ccg otseytn6tdbctt0l 7vm5otctsnn9sritbsv2doosns sb05npt,n'9bne' id65qn
#
# --- n = 2899, p = 500000, loss = 2.757549524307251 ---
# snds.ne5sv'48swtqs.mso4vts cfn1cnotx72sc cnp v4o6tautnsjfcxlicop7nnpwdxxr,cyl3cxhejp cgtgtpccnssvrgn
#
# --- n = 2999, p = 500000, loss = 2.757364273071289 ---
# uddlhn icem3nsszc 3nl3gv4.tdlm n  nc13no5nvn2 ms0vstge'ckctrebpsst.7omplwtn9mou'e.mkjztrdd,ezn.ncqdh
#
# --- n = 3099, p = 500000, loss = 2.757218837738037 ---
#  sglv fo cgg tvlgecc7logr0ansosoczscs dru9,xd2lvisy0ccsrtndeiseivgccoornjidgd9sl m7s7ot,s,cssc3eonqt
#
# --- n = 3199, p = 500000, loss = 2.757192373275757 ---
#  t2stdstb0ho'ctnt7ntbocoysoetor,indidcloxttplsbiccentfwds2s,nl7vcgf44fjufh qsnffe vm..orhuu fhr2tsfk
#
# --- n = 3299, p = 500000, loss = 2.757225513458252 ---
# dnuve 4c3xsts ccgxtjfscn cttrcoys n 2hvnh 58epynos9rn3gnefhbsgw26osz3gtgotrbss,zl4fhltxcqs1.ngntmnso
#
# --- n = 3399, p = 500000, loss = 2.7574422359466553 ---
# 5lccqyccophvgesjnyv9ew5nvnxfcs8nbngd3zcynsgrannetr8xcvlsh6'tsc'ns u jkac2y8ps,r7r tigm gfsswt81y5eke
#
# --- n = 3499, p = 500000, loss = 2.757817268371582 ---
# tcvrxvptcteiqcygehon,.n9 6nto0ctpgn' ttcifr vttsec cme2nutejntcpmnchnn 9oeoso3stntspttn69e 8g3 skb3v
#
# --- n = 3599, p = 500000, loss = 2.757842540740967 ---
# ttaaqsctsnnnsymas ugd t7.i3,tnlnllrqv7keseo.v, vnydml sptn2krss8nsskn1rosn'nv43sy2nlotslnj 9,cenzsfn
#
# --- n = 3699, p = 500000, loss = 2.7577736377716064 ---
# axg,tnnqrcjs gc 8rnp sm43o3tws576nono6recugctdue.6'vtzxx49c40o e2b.6tntecjxsn3vfoettrss97zvggcnsoosn
#
# --- n = 3799, p = 500000, loss = 2.759464740753174 ---
# cb7g c19msf2ttqi sd7'tbjosd3t6vknei 3cdoref,np09wccshvsiinndngs9tbqtclnle3 r'uz p4,eevtz6jt3sstns8dy
#
# --- n = 3899, p = 500000, loss = 2.760200023651123 ---
# tflavm9dzczn 6cetos2ll9vscesazfeyevbd nx.ts9es2ytcrnmn02f.no9nomn1tcynm7r9d tm6sixty,t'tapoda..uvhyd
#
# --- n = 3999, p = 500000, loss = 2.760157823562622 ---
# sdbsbnsj8st7mtonon rves0dts'pcql cdunccuoz 2lpcftgqd f rjghdnsnflnd9cenrsvtsqjon73y8tutcoso4 nca0ovg
#
# --- n = 4099, p = 500000, loss = 2.759909152984619 ---
# rgnssc eg7dtdcchclncsnq5r' etsl8scottvgy31ncy9pntngckdeyhcctn3s1te6v6sv5so. 1oco 2'oedtf0etc9sdoqmh7
#
# --- n = 4199, p = 500000, loss = 2.7598583698272705 ---
# sped1js twndttomgng,tnd9wwlcctnn7eqbvac5cns.lsosctsdecf3k dk spsnqs.ds3c ydc2a9uslxgoossqvns06ntigo0
#
# --- n = 4299, p = 500000, loss = 2.7602739334106445 ---
# km,tlu0xn7gsdlt2snfknswc5sunmnqt vnt3nsbtn.sc'o tjttondmnv.hnig on'casnf4m omcjse,9 .dmcn.un t'to se
#
# --- n = 4399, p = 500000, loss = 2.760317087173462 ---
# 98eocn90uqxfss6lltscotnano2bsq2dncsg sf6fuaeoec sncvn'nsktsv,tckyg0ectn ndqm vdtnxm3jtf rssfemv,5g
#
# --- n = 4499, p = 500000, loss = 2.762300968170166 ---
# otw1tn65'nnt6d9 xktfvss esn3z'coe.os8st.8nnrodcpcttctt0zjotws0wtfd1sgvgco3lti2iiiotr2,cnszvf em8bnws
#
# --- n = 4599, p = 500000, loss = 2.7621729373931885 ---
# rnsy tttcstte3xnvcnrsudn oclets4s5jtnswtcisc'mrrxktlnmnse d o3286p9tccv0s ii85ch utlfvrkcd81c'nvtgu5
#
# --- n = 4699, p = 500000, loss = 2.7619242668151855 ---
# tqota1,ts'd3unzknogdxsd.5dsmngqm4z csssszy tnq5oq tnv8fv8lhsaevntrlqn19nns.ruecptssaj8hczyes3 v2ccst
#
# --- n = 4799, p = 500000, loss = 2.7618441581726074 ---
# ytsz3nisosnce1l.ngt5tscn243znvntptsl ncmi2onsng1hdesyssngdqpv6 tnsbgsvb,osr7dbcest t9.tnnk7,topn 9 q
#
# --- n = 4899, p = 500000, loss = 2.7617905139923096 ---
# xpldvszgsctd 'n48'tcedt04dsn6tl.9zp aiscgl579dtccuts7rtzgsgtmfsrdgscedstcn9h't2fiornlme yctdynn st'v
#
# --- n = 4999, p = 500000, loss = 2.761782169342041 ---
# lqtscclgttsssocktavstcdwfh6g exnn'v or1dsshglcncof4re hst7swgsc0cceiedhp0'n4mhylyxo0akorc8ncc6sclnmg
#
# --- n = 5099, p = 500000, loss = 2.760690212249756 ---
# nsbr3to,essjougolv8yccot'so1esohabe' tnvsnvh2,sltr sgfoys3xlafbnnsdms1i2hgswrsp9sn27fssneso3evwtei1t
#
# --- n = 5199, p = 500000, loss = 2.7603442668914795 ---
# dt5tspnntdnrrotsoctet21atusw5m2tbsdhn  'ges5c 8jatm'htyxncten'tpofstsrtehk1ccsttde tnz.y v795d t19te
#
# --- n = 5299, p = 500000, loss = 2.7596564292907715 ---
# cgn3s 9cvs3c5,c5vclws atn 5ayn6s0td1'ntdox'eccea3c1tigsccy f  ssbcro tbq q, s'nrts9 odjn4m4st 8'tt 9
#
# --- n = 5399, p = 500000, loss = 2.7586569786071777 ---
# 4hac ne3gntt97nc1 azg'svvg'kgs0vs, meccetjcj7hphlum7sxtrkcksv9sdc3 ftvgsvt,ro1c.ldtaeottlesdf,e m8ay
#
# --- n = 5499, p = 500000, loss = 2.758380889892578 ---
# edssidcvhnynycdnntl5 5 to4isntsctnn0gcxts',eessoo a9.27cgicsszfsssc ccko00ntc9svbt3293foegnenglo.6yt
#
# --- n = 5599, p = 500000, loss = 2.758688449859619 ---
# tcco'1cvccnnhn p1tl0fs',e5vtktt3sfyocetfn uwboogrfndf3'vcontokgndxvtle.sdn nqtf,5cn l tgn,fwn1itticp
#
# --- n = 5699, p = 500000, loss = 2.758497714996338 ---
# 8'dyet1mdssc'e e'l19qssoc2znvnv nc5 ctcntywtozvwdttse 1psr0doz jv4gtwcs6t.scrfebldt2n gos2 sn78pjttt
#
# --- n = 5799, p = 500000, loss = 2.7583165168762207 ---
# ht,t'o b cc7ecccndc9e7tsv6gknssdodxxcft,t,gcteah f8rfntcnntsutnnu  su9tnx etlxnevnv1eodsgoeut vtnygo
#
# --- n = 5899, p = 500000, loss = 2.7578887939453125 ---
# db6kntcl f930obb,zcgdkq4btdkvczaecegtegv5ix6vr7svt53tslns.snreaekt t qu2ctd.tp,ncnnt3nltd4v zjsnsern
#
# --- n = 5999, p = 500000, loss = 2.758230447769165 ---
# c s6seng1lnt76oevsno stcgltl1p'h,ota7t  zintygbtsft8toc1t omcnoe.c vsgpnls3're0wdrecncyncoap.nc36lnv
#
# --- n = 6099, p = 500000, loss = 2.7573294639587402 ---
# pglnc2sptecrntfgr9y6,lde6cseh6nnzgofrwsaqvglzxsrt5czs.etilu ,os1,cpb7sl 3mjps 1tjc.s.us4zeu0o cda5sc
#
# --- n = 6199, p = 500000, loss = 2.759251832962036 ---
# so,bbvsoen7,o cvdxjf'n6sexsydt77ntetswenntntdbcvzogidsnteis4gs7xcsv4tl. gcret2 sbxn8invd5s3cpllnsth
#
# --- n = 6299, p = 500000, loss = 2.7595009803771973 ---
# rgl9svtrz5t8ckiymgbescpvcfxvnos8tdpq43kg r0nvbms 3s5w'ncnoshw30n6jgc8vr1wn2sc tc neg7qrs.9,sixhjtnss
#
# --- n = 6399, p = 500000, loss = 2.7593703269958496 ---
# spt.ovettx1itttcw7o'soscec28opoggvulf0ce1nrr0oykl8,ne0trz6csnlndsuccls,ppftatelsfnt0oltornegsccn0e n
#
# --- n = 6499, p = 500000, loss = 2.759380340576172 ---
# sln4sq9nvq  yb t2.ugosnlj0jc .son,dsn tesf p5c6ckd7oncsvdp8tvaevvgco1mctncs4 2n6zsa9fcfcntnbbcvsz.p4
#
# --- n = 6599, p = 500000, loss = 2.7592644691467285 ---
# 1zden0nsnotosqxcz03kq.tnnlse6f8tft'crl3ot2nsnb ph eumnt oevtra sfjk3v4vsktclnkrcg3stah7otossenq1cgs9
#
# --- n = 6699, p = 500000, loss = 2.7586119174957275 ---
# d9vons3dvdtoc3sznn xeemvdgclscthyggtucgtnt2phetc.tdsngnhk3ongcducncsdcn mvtttg2h6 cu mdcsfn,eknslytt
#
# --- n = 6799, p = 500000, loss = 2.7581772804260254 ---
# nsjevn 1u.tcgne. tm36ci 4jth.6vejnttot0nt3ctstglt 3oo6s2rlz.n5mnnp sycm,seenzdxtge5sqxssncncn8togitu
#
# --- n = 6899, p = 500000, loss = 2.7580254077911377 ---
# qst0noobnd3nc6ofnf6ovov5ccsmsfsw3t1cnttd349cobnynnadsntslsbodf98.25gs'fcfudt9   fo2dzsdntbbranitkec6
#
# --- n = 6999, p = 500000, loss = 2.7558021545410156 ---
# t 4a7d vvcvtlh 1s7cscats5s 5essh.ods50sonjozdbt9vtzans .ts sfl'tzotsr2sq9tssaveny1lt2t77oyykdt4vhsft
#
# --- n = 7099, p = 500000, loss = 2.756361484527588 ---
# co sn f1ag2x3 dpntkt2nfctbktenc,fg tsmg9tyittgmwc qcsdshns vct'hytjtjtbenlv1xl31dksd ktv36 ezkegi.ts
#
# --- n = 7199, p = 500000, loss = 2.7569868564605713 ---
# wvx.r0v2cusjnowauvk.sde3c.io.ssr2 ysnuc9vcw4tfr5s1vssnytnsne7oqsot6.vclvetve6s 2cttz8gt.dv ,gmzyt2ro
#
# --- n = 7299, p = 500000, loss = 2.756885528564453 ---
# t,z7tsn0d'tgfr23zldsgft6dsc sdg 6 2welddescgp7'.rlvgrgawve4vftntssn. ngorm1evsnmdeon0c8s'gl 0tsgvnfc
#
# --- n = 7399, p = 500000, loss = 2.756192445755005 ---
# e'trl56clcootd cd ioqqvr mgamdwvdoosdahg ssdlcnt6cy9ycsh6sccqlsytqgmge ofsihgdmse'smsiansst'evtrjcyn
#
# --- n = 7499, p = 500000, loss = 2.7572073936462402 ---
# srgnntb4ccs o4ksk nccatvjtozclczephostdevgydt'mca 985nij3sscngvn2f c zzlwcnxeln7 ntlejcd7,rtdznut61z
#
# --- n = 7599, p = 500000, loss = 2.7566730976104736 ---
# 8sss0jcmgc3cndc9nstcsstitncjlgttsmr cnuegssdtqn0dtvd0ysno34ijo8tnc3'0sstsdtoseatci'.lnl govodtce7ns,
#
# --- n = 7699, p = 500000, loss = 2.7558839321136475 ---
# xtotcxydnct'emtee'onnogmsdnx5nqtmtunvodqng2tvdnt6uck.'slmsbtt3c t9serinlgoeocm tpxtlmt.'2urcvngqg8s6
#
# --- n = 7799, p = 500000, loss = 2.7565882205963135 ---
# ,wssbnqg0nzei bmqst3,svtcif0devosne nensevsttffh'j wn q,'nn9vnsjgeornv9trtcdvsnjdtruagjt9ccno0scsdr
#
# --- n = 7899, p = 500000, loss = 2.7567250728607178 ---
# 5s9igr es9gwsu6koft6gnle n,sps3vtyttzacn,tn7svysz83cmnzj eecotgnsc44ssk9taaoss5z5n3mvtsltvnnnnkte6dt
#
# --- n = 7999, p = 500000, loss = 2.7570290565490723 ---
# toiyggtk,.2ottsdn.mznfnfn5cvcelot'ezt5 sqepgsenrn lmrju,ljfctre7ebdo6o5e4dmiskqtldgzznutrtz5'ttsqt46
#
# --- n = 8099, p = 500000, loss = 2.756833076477051 ---
# nnc sb5e'flewdtsn lwnqn4ogktescdtdstsdn48ohnkvdslysotiucps4e xentlr8t9nsc t nt,'e6jzb1sdsttgkcllfqcj
#
# --- n = 8199, p = 500000, loss = 2.7572031021118164 ---
# kf7gt8tctdyon9vtsnt1yokoltn722vg6ossexc9'onsrgf2cn'v'nnfc.stqdo8,yfccgn7fmnqbecwstt4mm0svtgpt 4nnce
#
# --- n = 8299, p = 500000, loss = 2.7567787170410156 ---
# t7rs ryctvxonskcs'xnc 7n1 t.jxe2u,nuj rtsgel7vo34tcocsoasnddolqnt82snlc0eigsc8 mnjne8tsrscdteen6dh 6
#
# --- n = 8399, p = 500000, loss = 2.7569761276245117 ---
# zzset0ee.wotl3ncdcg2mot7tn.otot84prvzy,nm'nmxvhslepkvs,wsko.t76kn78tnjba vjp7ocsjwcc2d2cl1uce o4b2 o
#
# --- n = 8499, p = 500000, loss = 2.757434368133545 ---
# dmd  nks7tsr'rofjos lzshsi,tvd6nsdvuev7otc ,ldzodsexwber n4xjtutd ncscpzdtlvtcmstev15evnm odfn4c7wl7
#
# --- n = 8599, p = 500000, loss = 2.757855176925659 ---
# gstmfc0s1fj6 tdonchl1lt'eqi7le8c8sg7tsk1ctgsnsksl l57dcotw7ssncnsuj7gc,..vtccevcc0sisvgg8isosz ldsst
#
# --- n = 8699, p = 500000, loss = 2.756861448287964 ---
#  rodlc32jvts ngsnnvk2r8nt1sxewvttvtny'1svt 0ss9yslkcmshl3tcnntvo omzogentn nxl6g4d4x vds72sw59 n8ftl
#
# --- n = 8799, p = 500000, loss = 2.756878614425659 ---
# lg5 6,.56tk kvo6suu32nkctax.ldtthlew' c dodcfed1trd'1odvs1cd2nosdlo4ln.uz3nls0ol cs8ct'o6odn7ecjst82
#
# --- n = 8899, p = 500000, loss = 2.757235050201416 ---
# v6fldt6tx4 n5sv63vc8tjud7gs43cctdmt4rglce rc'6g,cgnvooo4htes3aknr0efstecntevonv,ryt4k4cin3gb ktbashn
#
# --- n = 8999, p = 500000, loss = 2.756448745727539 ---
# 7'.tfmcd,zkycsjyad't7gxxsvabdp,v9nacy1s7dqnwttgtf.ogactcdjoke7ocjao8w4bh pbtr1notio.pnfntfgcyvq gjsp
#
# --- n = 9099, p = 500000, loss = 2.758291482925415 ---
# nt ke'6dbw5vfqtrdznngnent ,stn9nwino5'ocslc68,o19k96osnccva1o tconve  en3ts18w0r2 ctdit19stomsncnw3l
#
# --- n = 9199, p = 500000, loss = 2.759334087371826 ---
# ostnio sbmacatn2o2nrn7ructr4yngpvoo2tl,6ju4gmmpcvbcs9qnyod sesic8run7cnlhxsgcntsrctszcscmvctssficosc
#
# --- n = 9299, p = 500000, loss = 2.7575793266296387 ---
# dd6a7cuvn3d ttnc31pwt.e.s tsjsttscsigkgoj dsevg6evsow.4jwl0tcee2,4cdfnbsodet5s rbvman365v6edngs32tll
#
# --- n = 9399, p = 500000, loss = 2.7571096420288086 ---
# dlttdhsose 4tzcad ednnvgpbc2c fd1bvhnfon3hitovasn.vn l5'ex9xzrgntc.vwe mvsjd.gwvnssn'er2vfcetlcg9ces
#
# --- n = 9499, p = 500000, loss = 2.7568602561950684 ---
# lnwn.hscfy79,t9drlzi08odgnvsrntttdkno,teqdt.tnvsttgf  thds40n2t3nstn 7tnww akpvnle'e7t1qbs8s erottne
#
# --- n = 9599, p = 500000, loss = 2.757260799407959 ---
# xn34spe eggq2h2mrssr5nslnmscocot1inc cosjmtv ktwpdbjsscqvcvsozemnseigcgn.gcyrljno.,svtvl6etmy,swckk2
#
# --- n = 9699, p = 500000, loss = 2.759204626083374 ---
# zdnucsct6sb3n5iescjfsrnjv nytdjtnej,snel1lksqngrd osfc3ss.yst4nvp ,vtseeopes7ve  ssuftxefstncint1vmo
#
# --- n = 9799, p = 500000, loss = 2.7600417137145996 ---
# mlutd ccdcfmtp.ostoqnr0rw51gm35syo4vtt2o 1tkmnpo5lowoanogsgb 'dl shevgkb0x21f.mslpec8lenpghafwf'6dns
#
# --- n = 9899, p = 500000, loss = 2.7604196071624756 ---
# sgvdsekgcpe  6nttoltntxgdjn1.bqjsi 1vtch2d0emycjpn1f f5e ctipsxd xttx0tztsxwcc8ozssc1cpvvoot.evctdeh
#
# --- n = 9999, p = 500000, loss = 2.76005220413208 ---
# lq1it7jewnnnxjm2pdxsosf 0lznsn.scl t nhts9cogndzzneyetcqc6rc 's2a2ntdbstnh1 conr6tbj2meyty nj3a53q9e
#
# --- n = 10099, p = 500000, loss = 2.757251739501953 ---
# nyzsmntf3stfno.bss9ote0dtdgd'tow0d3 s bn3lphvt1ts'3 sgixnfamcvgntutts1ocs8 ce teo4nshotctcit seendct
#
# --- n = 10199, p = 500000, loss = 2.7569220066070557 ---
# ecs,ncobnd,an0tnlt7tttt6j51q cot rr9nf8 ytgiteivcnb,sncr1ccon tyeecsoxrcicdpco bzenhud gvsff ousd36o
#
# --- n = 10299, p = 500000, loss = 2.7588164806365967 ---
# ctx1 pnc'cqmiothuco1nnx' vncsvdcnsq4e,stdehtgsl jvcctasdos3 xe6 sn4dpyz,evxnwdgnnstndmhjh cd'esyc.n3
#
# --- n = 10399, p = 500000, loss = 2.7566404342651367 ---
# ftjng7zp3een4stj8n2 nnzonao7 stnfcnecq0 4ctnos,k vto.n 7n.l8fnfm3vw7t nmzs8ecvo a4ic 3vv.y3dfwgosmo.
#
# --- n = 10499, p = 500000, loss = 2.756460666656494 ---
# ietxcclcf11ud6gsctlverhncmtteon.2 ys0nnks5cnccstvmdjlta tg'svrfi1l o8m gnsn2taldtsgecbxdenh6gstdfvit
#
# --- n = 10599, p = 500000, loss = 2.7557828426361084 ---
# 7tcc8s tyd .dgofcoctoa1rtxnnn 3j 1gssyjonrk0lc'8gn5gdljem6e,diqnvtetkttcssm7cn.mddgtsfttnnruss9w9nwt
#
# --- n = 10699, p = 500000, loss = 2.7560205459594727 ---
# bc3nt3u4cvgjng2vontt3bjfcsqgfgshnet6hgn0n0lj8,qitd3uffsn sf88tcuvtoqntwn4co.'cgbehnosz8gngfv.ut6ycw4
#
# --- n = 10799, p = 500000, loss = 2.7575738430023193 ---
# 3m g ttolwxgatm ms nos7nnstdt'e50npcs f9glrkotv  obo1ott61wlner0zgn62mnl7nv fsc1ee1vj2oqlgndfs senol
#
# --- n = 10899, p = 500000, loss = 2.757685661315918 ---
# 0gcpltcn'tmv0y4mvb neseenstsmsnsj7sov ftvssqiflvs.stmg scs en7nvzrsd 2e,ovsirdsvcrktrzfn98ytscz6tron
#
# --- n = 10999, p = 500000, loss = 2.7572810649871826 ---
# ssf s5l2rwdp szto3smvs7odocorlesvab ,8msicpr n9ntcneno1n'z ,lsv7nt''2myncolysgouzcoeghcg7ngt tnvkz w
#
# --- n = 11099, p = 500000, loss = 2.757322311401367 ---
# vsphmzuhn csoin.jz'e o1aosspynejc 6tt8o6 tnnxqtgvhssn x22gn9vdetbnxwcluiry5txotdn6nt29eh,hssrffsvt.c
#
# --- n = 11199, p = 500000, loss = 2.7567036151885986 ---
# x c4vodoc5s4k9zcnts0nrstdtgmfbaslcref,xzczsonoh s4gv7sg.2ntdj'ncs,odc.lducqt9s td..ovrcltnnn3ks,lcnd
#
# --- n = 11299, p = 500000, loss = 2.7565059661865234 ---
# j6qd dsnd 9bbronqjk4t  b65bswcg,nn6idcmzcgqlt sc ,ltexz1d2.konet sc4 vtemxr ne0o 1esnf tqsnvgp'tt3wo
#
# --- n = 11399, p = 500000, loss = 2.7574596405029297 ---
# g cn.sles6a7ncnnkmtc  nrnrv147rb1mn'inhc0.,deft4sp.efsc9a1tbdn4bspcd c.ykspz.tn2n1lcyse ptssnln1isto
#
# --- n = 11499, p = 500000, loss = 2.757101058959961 ---
# 5dsdstz1e'redmttsasjcrqllug.f c7nnwntttntngp6nf4cd wk4ssqli6n2e3csecc.809spvsdscigq'tspr0lntatskstyn
#
# --- n = 11599, p = 500000, loss = 2.756976842880249 ---
# 7od ninnttvbgnsnnmt gmastan3dl4wt6uetnttn'xs qbxx ecaclnyldr0ksdecvessa.2ossncgts f2t 3ezn'6wzndv191
#
# --- n = 11699, p = 500000, loss = 2.7570745944976807 ---
# q1 glse'nepgtttyaszlxfdddewmkjntpclftnckmx7svcpcc9s l5 lcokvxnttst rcncnsc5y2do octdfsdm7moanntesvll
#
# --- n = 11799, p = 500000, loss = 2.757585048675537 ---
# ,rowbnlttotc5428x0vslte'pyito0vsn ncmc,d2n nc09' 9o tee1ooyjkoy2c,efacstjsrdpgdsnonwfp0'soosqc rthqe
#
# --- n = 11899, p = 500000, loss = 2.7571916580200195 ---
# eoncydn80mtemnx nn4csqfn 7ccsxgcggepasdslm3'vue7ezrucvtd41toteytaodcsno32lve.o4cntn7yjdo2scssq gtcmo
#
# --- n = 11999, p = 500000, loss = 2.7569668292999268 ---
# efcev6 9ntj6dd3dncfsrnvkosodn3niuptuql,drtcdcofene'otj.foa9nt4eu8ug4gn 3ztit tg6sqisec34t2ntgvofwh1c
#
# --- n = 12099, p = 500000, loss = 2.7563679218292236 ---
# neto96mysroeruj yl3vtlnen1t4l1w9gsldenxcnbyn'rmrq es1r5lg3tqtdc0ng ccnssajc3t wzmczdas nsgrestr07oxg
#
# --- n = 12199, p = 500000, loss = 2.7562859058380127 ---
# .nstgmw'ton5ttjbt7dowgn.tse49e06x1sn5vlnv6cftenccffrs5cd'yu5ngsnntj'9dvoboqjx rs6nksbcensvt me.dd 5q
#
# --- n = 12299, p = 500000, loss = 2.755497932434082 ---
# 3kjfrt 0slm205ftr.nbscct49c7s 3rsslpcm,ntncdc'eana0ckpxtcoc6ftfetlvtsdns,s1tnnngtulopt2gsnfft8c lkx
#
# --- n = 12399, p = 500000, loss = 2.7558796405792236 ---
# 4nrfdoqdng.ktn9esbgea v3d'vw,b nrc6.'ond xofi0' 1lfen1g gsj0ogns r tarc2srfnlsxnn9o2xkctgefeditnso1b
#
# --- n = 12499, p = 500000, loss = 2.755779981613159 ---
# c 'lsu0qi1hvsdws4r0stt2ne3cmitecmtvc9ccpg3xpcs8o5yo ns.eztrsgr 6noed'8yy e'toe5s7f2zrifbgn6wanst3tyd
#
# --- n = 12599, p = 500000, loss = 2.755618095397949 ---
# xcbmrnsitgqislvspxcht5kshcenuc.dvsx2twnrdea8tntosllmn gnfs30 s6gls9nnv3rtcesvtjsr z'drfvv0w2tlv5.nn.
#
# --- n = 12699, p = 500000, loss = 2.756296157836914 ---
# sfo8ncnqnb0a3ortssmt 92n4lwt2dnv2tcudcnreze81sonr,o2lcvx8slngn.6ztv0on2tlc.h oo ccth5b9gt vqjfctn.2t
#
# --- n = 12799, p = 500000, loss = 2.755744695663452 ---
# yct6ed3sdig cdnn4ty1cl,ca0q2cofjn nslkmchyn,vmztcnnnz jg7cvc4cetfrsvgmuvsecsj cctf9sh7n.8gsvtcsossxt
#
# --- n = 12899, p = 500000, loss = 2.754316806793213 ---
# r'd2ctnncvnotvc1s6 ,cgs spsykvv5n6ctt  zvtcdq7ydnczv qns7n9vcesox0vn4tsllssslnnx btgn,cjdoneehs6tttx
#
# --- n = 12999, p = 500000, loss = 2.7549872398376465 ---
# cp s tks4 ss,4oovl'st86omnm'gco d5euoct8td1sldvdndktuemc9t9jtvca6gde57fens4.sov6srm79ccanebvc 9'6lsb
#
# --- n = 13099, p = 500000, loss = 2.7556726932525635 ---
# clnng ro7gnntn,gnnwtdnrs.tinsmeoze5sxocawt1tcg60stcmxcshrqwreqso8k5ysylc1vtsvvhtltv969nrce4td7euvnbp
#
# --- n = 13199, p = 500000, loss = 2.7556605339050293 ---
# dni1wtn9vnnneen8cdw1csn3clstdxo xts 7 lsfu4syrrdddevqsxe't 60serxehsltt3sstsqttu.csgns.mtgs3ds,sd9va
#
# --- n = 13299, p = 500000, loss = 2.7548155784606934 ---
# o4sonsnsz6ng w9crkons's2aya8t4ec2ssnfiu nv88iettg1lltdj3onshcgtqae. stmnelttjttttpt7cdsvn.9titxttwyl
#
# --- n = 13399, p = 500000, loss = 2.755577802658081 ---
# b,g7tsi  re melcnztjsl osnpsndoo7'n1osferhginu94cowpcvtelxddnp,kslog6s 3ef nweoeov1c1t.qmv't,ftlzvnn
#
# --- n = 13499, p = 500000, loss = 2.7554309368133545 ---
# ze1t csemt0nnslunld.9oohv.w9t2ntn6s2swl.e 8cg5sn1vn9ssmhoptswxnmn6y0gmqskmgx10srlcis0b3qscbf,9lcpers
#
# --- n = 13599, p = 500000, loss = 2.7557787895202637 ---
# e netevzrs5fninlidcf6d t.t3cdmctt1c672gdooatuv2nxcpm8ncsu'n2sblas2dcc4sn5hqc  tetnr excpfstcacgtc6.n
#
# --- n = 13699, p = 500000, loss = 2.755558729171753 ---
# vtspctnt5o2nc6n1msdhoe7nudrn1'got ynecl5wys7srsgoqnuisounndlllwlc e n3rswonhxtkddrsndt7qzslntsn8n vt
#
# --- n = 13799, p = 500000, loss = 2.755678415298462 ---
# rowcp1cn o,t.6cewg2evsetno6ogn27rsfte08dz13mdmczdc0qcnv6atck03ttvt,spss9ntete'asb30n6ssdu,t'wsqsslvi
#
# --- n = 13899, p = 500000, loss = 2.7555994987487793 ---
# eswtua.jicvmoz2l8cse5toi8g s jo8ssckbssc0ufc3n9c6tvtoylgtcslsgr3 gqkfec0fos5qcsol3c 2setnn93461rs'v1
#
# --- n = 13999, p = 500000, loss = 2.7551698684692383 ---
# swsepngv4x slbd9lj3rv4te6.cntgx4che1ifc9lf gmmmmetjc9on ld d2et1t77t vktcgjts7tns  gn4gt5ln9otm f4s7
#
# --- n = 14099, p = 500000, loss = 2.754774332046509 ---
# tyc9snls' nect'bnbmhbey1oc,ntjazcgtjpl8scnbth3e0vsm62njls8c s7c,ecssajtuscs4 s sr9wcteme, eatud6ut1s
#
# --- n = 14199, p = 500000, loss = 2.7550580501556396 ---
# rtnicvlkgyq6y.nnzkat'kto69 sxmctntlos35ltbw'l'njscnssgkctt2ttv oshn9t8gev2cch sgpcttgnftf pttte97ftn
#
# --- n = 14299, p = 500000, loss = 2.75543212890625 ---
# wdejrcnleo,elgvccgsjo,vmtofkttmc4rtns xz5cgi8s76 02gsf4loss15jyn8fdosso1cosksscnd08lbcoqdxw .em brvw
#
# --- n = 14399, p = 500000, loss = 2.755847215652466 ---
# zsnn05stvc6xroccjtdwvzvo12sitssccmnnddntscge 6qnvr7igugsoo.cflcc8eelousggbsjc8ei0y1 vnr ussrx,cnytcr
#
# --- n = 14499, p = 500000, loss = 2.755553960800171 ---
# r9siobpnfncm4wsh57 cfsc0m'kmsucgx3tgc. thsg0csjdttyq0sltr8dz ste4ms0.tgo sstco7fstvogd6bsvntottt s.6
#
# --- n = 14599, p = 500000, loss = 2.754574775695801 ---
# t d1cryjgc34nv2l26nssmw'7setttshwcssrt3sy plmh e1ek5wcsdec8sruggf7s3.38eotn tded'7onloznkvdcdtqdl1c4
#
# --- n = 14699, p = 500000, loss = 2.755364418029785 ---
# 9qgsgclgmzes ctnordcccr1qn wysme8k7c0totqnvrgbc1os5s5b.s,giosor oot 60k1s.ekvcc6vgsk drtngnavn.6''fd
#
# --- n = 14799, p = 500000, loss = 2.7556653022766113 ---
# vco3 .rgzdry,lto07ecfun7em7tl8ncqj2ufs dsse'mftnxnhs dxttmcx' too0vkombosn slvdq5tlil5mgttozhtc,5l
#
# --- n = 14899, p = 500000, loss = 2.7556746006011963 ---
# t4czhq tn 1stsocs4sqdtdvtv6claft1'mcx8es26. nshtnsticdnnspob lfuodotpp sle x1nt.os5c ua1dnoc  tosfnl
#
# --- n = 14999, p = 500000, loss = 2.755197048187256 ---
# 6pcwtey,ogsnnuocsv0esslvvmydgmsoawecg7v4iifo6cgc4g15essnn6noftsu1vmobnc nctsngenar,6pc4 sncvn8kn6s8y
#
# --- n = 15099, p = 500000, loss = 2.7559220790863037 ---
# n.ceoetw2gteterztce 5see0ngonw.svtmgchjf2ktnw a astvitl4onl4sx8odv,gtdbtptld67ubg5swcnrvc3snbpo0vssa
#
# --- n = 15199, p = 500000, loss = 2.755248546600342 ---
# tpvefn nonnnp5tkr 3nnczcuno9  tn8'tn2ttskntt' vitvhnpc1q tnnnae5 t.3nepr3ocsmtcromv'jopck8uged2sf2vo
#
# --- n = 15299, p = 500000, loss = 2.7555580139160156 ---
# ntss9tetncq7tgs'nft 6dtecst5v,esqjs.ndcqj4tneose7 .no fsstz6w,uboxs'enntb7 te07vs8hannxseswwsnfneheo
#
# --- n = 15399, p = 500000, loss = 2.7559781074523926 ---
# 10cf3dhtexnts09nzcsetefmsgqoyn,nngtgnn.ciga nvg3lkddop dtk9y2evcrsogr otu7si ygth1hse3o2nmvlriwln6sg
#
# --- n = 15499, p = 500000, loss = 2.7566514015197754 ---
# yu2hskl,lss6ctnlsds8.ottca276qzvvhxnt4ok nkcemh'6ne1e4ndt ydbve vgizx7tmlsnrlzn7d 't9fuenos tbonszvj
#
# --- n = 15599, p = 500000, loss = 2.7562403678894043 ---
# cets03ss to0990jdlitg823sa vlfo4tnitnyvntffsaz7yoehte vyolscoolvtststdltcs3ssrgfrsvd.ocsdosnvslwsyn
#
# --- n = 15699, p = 500000, loss = 2.7559521198272705 ---
# 0.1tt knsnzxlp,dn.tdtcf63b senskkol.kvsnssn9ftnd4kzn4nfnsmtl,tcnv2'lc9v0vvpnn9fx z a lteedsec'ee'scb
#
# --- n = 15799, p = 500000, loss = 2.7555580139160156 ---
# ba snev5cp,wnyao.2tscjncvsvnp14psttschb3kls7wsncpttdc7cdccl.9bsnrzodwwtt,'vts j3dd2vvrodnr83trlcebdt
#
# --- n = 15899, p = 500000, loss = 2.7558417320251465 ---
# bjc'9dcdncwvm. msoopac.cqv3 fhmmln88rzt0uxtitl7et 5geg cs'jctxngsws2kg.sdeoxjcvco cs2d8n5m7rmddncndc
#
# --- n = 15999, p = 500000, loss = 2.7556352615356445 ---
# csrtt 6teny0ddsv4vsn5e5aon96snn0 xxctg jdthpcx ait'cstmslkl8t35nvcer9ntoei hs7n92c1lnds.rssowfrnsrv4
#
# --- n = 16099, p = 500000, loss = 2.7563562393188477 ---
#  '4 nengscskvsmjetlfoostserof0szcnxaaen c0entqcvadw, gayv rdlxohtn ednhyihstyhty 3egcb2ksoqvsolmuusv
#
# --- n = 16199, p = 500000, loss = 2.755913257598877 ---
# et2snoqzev3edbbfdlstbnipssl atnto slrcg dn.e4xxnjvcoase,cbzyj10unb0d1nct,'d.9ry1onocds syctveogcw4ob
#
# --- n = 16299, p = 500000, loss = 2.7560813426971436 ---
#   av9ephgbd4dutc.n99tv cl1nterysnqmrdnps6t5rcpto stttimorlnfs dt26k5qsn6nsanln1ltiz134c6nmem tntc2 l
#
# --- n = 16399, p = 500000, loss = 2.7558329105377197 ---
# nmasrn8,trlm8wlnd2ctnlcsdg2qmcnnvsyaascdxoebbcosretntgn vdt'  iztosvvog2bmnngsngj't,gtwrslnql5sw igs
#
# --- n = 16499, p = 500000, loss = 2.755472183227539 ---
# cnnlnttgn10wafn4ecdysn5dcl'soetrnnnt3dv's tyvqmn,jns5xfmiokt8bch xdvnrs xsot2sjhtssxtngt9e1yo's8teod
#
# --- n = 16599, p = 500000, loss = 2.75542950630188 ---
# t0g,t9t2oc ce nho'sgyrcn0cs8wu sctcdjtq8u02nrftsssttstectosvcbp bdqmdecavdnt tlvnl5gmsggortmcrso ns3
#
# --- n = 16699, p = 500000, loss = 2.755117416381836 ---
# bsdscti3,tj56eeslg5onn4sgsensu6rmgx rvffixtgtxrrvc03gtst7lcnwdqszsvp9woosf5iynsnden5dszmetkryl8g6emx
#
# --- n = 16799, p = 500000, loss = 2.7559916973114014 ---
# st es'tnka'1od4nnvty5nrin5tsrhccg7y9boeg'setsn1ttlf s05mpvlqsc9fa'cvnl28mxszowne8t,0ee5ndzwsd27ussda
#
# --- n = 16899, p = 500000, loss = 2.7557973861694336 ---
# ccnnjcdolch 6 ss3on9sknvt.sknjestlvoddtncvtc8fsctrmsv svpeg4yzogvhrvrsd5.elshntt gymneanmuk8conqntnj
#
# --- n = 16999, p = 500000, loss = 2.75458025932312 ---
# n.ss9n0jregto38gn8ke5zn.ssgsdcs5tcmnc 29vh0ofu l3dnbhn1cn ynt8smom1vlns e8ha 196glocont79nsehcmrgyjc
#
# --- n = 17099, p = 500000, loss = 2.75571346282959 ---
# , rcoso7rtct61zcq0ldue3rgdno2p8dgothtztgnksa.ccc8vndnqcas eenmtullv5st4fi8nnnnn 2x,.6sttbmokqjn3fmnn
#
# --- n = 17199, p = 500000, loss = 2.755337953567505 ---
# caugtcszp5nctttpvb41c.nuntcgtc ddntpi3egutgttb tf  t,tre x3ns 6nrt'ltwq j2w'taodfocn lms6vo  0 'krqv
#
# --- n = 17299, p = 500000, loss = 2.756105899810791 ---
# mvntim 1htck2tngn7bivclenes,zrs'f4ensdnt'dtsyhkwgdbc assdtbqnc3cncepxji.s758v nosjknlov5eno3znn3nznd
#
# --- n = 17399, p = 500000, loss = 2.756990432739258 ---
# tctfttnz0asmfx8mgjlnkc48ntontqzmes9intscee36 sot,rkstprrne3roct yny 37oksxcz7ltgam'msmcdgrnbxaod8unt
#
# --- n = 17499, p = 500000, loss = 2.757707118988037 ---
# lnbctmntnllftscdcnnsy s4efnsanbom'2ttl1trmst1itcrtotkf vsuscocac1lstttryncqzcev fyntp'cny a346nyontc
#
# --- n = 17599, p = 500000, loss = 2.7575912475585938 ---
# jdnin25etpsc8sflds4eigs 'nmc0n9 nssrqas,mswtc424o 5pon kosce dsnoc p8oceco.tleclnsasgsmdyh3ytncqo4rz
#
# --- n = 17699, p = 500000, loss = 2.7569494247436523 ---
# edens5crn'ttsslgtcdavn7a5psidyycei4ocu.3tevttjnlpd8t2byi7xltn.nf3l1f9vyv j 681y7'rnnt7t49topzgsnbctq
#
# --- n = 17799, p = 500000, loss = 2.757297992706299 ---
# n.nfxx71mswx1xs7yf.lnm tnpndnqxu0yvvsalstrnnktccd,v4jtmeebgn11ot6qontsuj,hb9snoxsfzhgoe7 nydnoalttdg
#
# --- n = 17899, p = 500000, loss = 2.7565853595733643 ---
# tcc3c5udyswtcncotve'.vd7ttsvfounsd.sogglzltpsgo1ttlws,tvrqnnnewewdgytmslth3tav9ld7qtv9tzc vctta'dmtt
#
# --- n = 17999, p = 500000, loss = 2.756540298461914 ---
# 5ojrtsnzowsaz9ettdsg cntarsjcscdsiy3,htztnssnfn, lce 'caans9q cwegm7t.t tvd70ntitu1nnswsb4tnt  cy1p
#
# --- n = 18099, p = 500000, loss = 2.755908489227295 ---
# 5novln 75jsddecue9zogv r.ytcx'ksntbkcnvsddonjnnmqsvby6fn2vns8sadfygnorre7 mlec vgccsavdncncjstscdgl7
#
# --- n = 18199, p = 500000, loss = 2.7555794715881348 ---
# tt oeovmulyocp7gs6, nvsen45fe,wcnev4vlew v7fx.btqjpnucnynsns tfne5 tlcnvtab8lp77v 0ncxnl co8 tucc0go
#
# --- n = 18299, p = 500000, loss = 2.7559244632720947 ---
# warnczijtvnf75s25mvwsano1sncamedtv5sxmutj4 h3ntlfcsdw aln3t ejf4'satshnstvt8lsercnctgfxinldplscwdvnh
#
# --- n = 18399, p = 500000, loss = 2.7565934658050537 ---
#  7r.j1 'sa2ll5nsd3ri9g6mncezeeqec2s9lc5rntxnn7cnxsdeng39u9dtnpcvog2rjdt9ntnnvr9x'eh  fct1tw66tfc1cfj
#
# --- n = 18499, p = 500000, loss = 2.756803274154663 ---
# sttebcdrobz' 32nn2nv cmohqvktv8gn2nxnnxelf3evfjvent.68hvy5utszw2gtp ccxmjcgo'strntctno30otblcs8 unor
#
# --- n = 18599, p = 500000, loss = 2.7565810680389404 ---
# n50 nlc1l2g na3rssu'jdtoskrpvlc cm0ns 4j st v 6kendsfnwslso. n.g4ttw3fdiemntojscnt82u9scceas7jsnn  c
#
# --- n = 18699, p = 500000, loss = 2.7558062076568604 ---
# octzgcqscb3ti4vfcognt,enp4 ,gn1xgtso2zizl47row5wrz4wcvyangotc,inon71nyc2ho6cneano gfncdte6sgimc9stnr
#
# --- n = 18799, p = 500000, loss = 2.7551088333129883 ---
# ne'ssltsmkod gne, dt db2ltnc's3irnfhmq1glo'qtcsottedbc,sintuz idotcbd1dnsksn mpotz .ced5l,eo drgectd
#
# --- n = 18899, p = 500000, loss = 2.752774238586426 ---
# msccznce 'nlfllanl crdv'slsvrwmlicnign3ncc2.kn9xejsurnfqsesrtgietcod4.ottw ndoef9gatczghscfoczleasrn
#
# --- n = 18999, p = 500000, loss = 2.753281593322754 ---
# dtdi, 6bod rnoy9s2cb cvnsknvcs.n'9p txe5r,s'8qo'vstty'erohtva,xed3sxvfndszkvenng9ssddlmnnntnr. chsn6
#
# --- n = 19099, p = 500000, loss = 2.7536582946777344 ---
# st0gd5t1co7tcsnkbn7o7p7csoul3entyx.snsmzek,lblh.tstf tlc,st8vcssme9cenv,emcdnt1sn7dr8gxdelt.mgsitboy
#
# --- n = 19199, p = 500000, loss = 2.7530570030212402 ---
# t3ytsr'vbntat03nntsdv.ts9ztcn8tmao 5t'rvslshugy51'giesdctr.lpltctbisc8' 40ads9nc3soctcedenh3wsssn tq
#
# --- n = 19299, p = 500000, loss = 2.7539658546447754 ---
# cukget gnowpvc9s krifdsitc'nosls6ts 3esk2eyabcn4yz 5s5ta,dacw 3n5pcoujyenog1tnemtv4tt3dnjsqsddtcd bs
#
# --- n = 19399, p = 500000, loss = 2.754218101501465 ---
# xrtgennenncyev wssct 8ns.9onosmtfuntdfo5,vg8n,.0t tcsic4mzdshime ,xf1t'cpqv9drc8jtndr1s5rd0se,tssofa
#
# --- n = 19499, p = 500000, loss = 2.754225730895996 ---
# a9i8torvttksl2ldvtnehsards 407ktecl6t sto ofsp9yt9sgcsoqsr onsnbxusrs, 4d1escnylwt'a0hcgov3poct2oil
#
# --- n = 19599, p = 500000, loss = 2.754702091217041 ---
# ongvtn'4gcevt77fi qgt,ckdnetx ropaqentjnts07escg5 51bsvwgqdcltwuenzge lcg27odcelwnm9gdo4scmgs4 etscl
#
# --- n = 19699, p = 500000, loss = 2.7553412914276123 ---
#  l'sntsc2cstno3yqghnvtt4znttulwlotspqudpcmjcintn0dcfmsigvsm3c5strbsi66vtnstget4oc8qsr.,rds6c6xsk8 de
#
# --- n = 19799, p = 500000, loss = 2.7552871704101562 ---
# 0scclvo'2jd5 eairrl ftdsnqlngncnnocnojelnggamt g.tzneatccetnps.ad2ctscsnoswcmyusl7nlcj8 es nrn7ts,no
#
# --- n = 19899, p = 500000, loss = 2.7562694549560547 ---
#  s,n l de6rt vsecto2ssjhnf'6osnystsdtnsnoghycntv 8cgk1'7tcohldletuc7onnw9wjnx3h2441brc ts4ucstxtrie8
#
# --- n = 19999, p = 500000, loss = 2.755615234375 ---
#  dc3cilym8smgosp5nto5stnmto 0'.c01tnnzoen5tptvcccsft s,ts0czmntmnd6risvxek tsv rcmeltorxagoor1cicv0l
#
# --- n = 20099, p = 500000, loss = 2.7551565170288086 ---
# 1f'edcvnq8's'cefnftil.0ojapk x.zyns'mvcnfth 6sb6d14 ny5ncll'.ssrvocdottslvnn,cd5lt6cwnlltsd  nsc.hlc
#
# --- n = 20199, p = 500000, loss = 2.756162643432617 ---
# gvsocvvnoktnl5sl 3c,2cpwgldxtnc nvsgggnqvcsvc,jkcxsovtnds1rmtnriqdcsmcwjv7fotw04ctg63tke6hc4ttthls h
#
# --- n = 20299, p = 500000, loss = 2.7546772956848145 ---
# ,dttsocn6c'sc4ls1sgc,s mtnsms9xxlgugnzs8hoknrlrxele4mv1nnt7hgoucdw lpcgy.s6uncns3i9xhrg yks,lt24qnnl
#
# --- n = 20399, p = 500000, loss = 2.7546839714050293 ---
# onts s o83ss93rlbh dscscpo4gys2d,hcmk sqdn cve gedss2.sy3,.,tzdec 7 sncntslnsrlcrcesn6deu ugslvgn27t
#
# --- n = 20499, p = 500000, loss = 2.7562601566314697 ---
# ntse3eg.tegwkge2nlaogfnsvsdnptzvfcstnsccddscec,k 4o tvc'ttdh4tjdu.csdnqne dnf,acmjn8 cst6nldc8.swd.r
#
# --- n = 20599, p = 500000, loss = 2.7555339336395264 ---
# sstde z1fo n2dh  svdocygssesqjtsco8esnhj9iktnss nt3,gtclw' tf2s7 awgctz stknktrsjl,k4etvo.dsjo h.w.t
#
# --- n = 20699, p = 500000, loss = 2.7567191123962402 ---
# lhcl.chx8dtoettsxsoteoor7mf9xvs.stnvksdtyloivelldgjd9ltp215s1n ts7j'lsd9vzv3ctceslbentogiatnjcspsvs4
#
# --- n = 20799, p = 500000, loss = 2.7571914196014404 ---
# c'stlc0,9ogem qxkckb,omzsetes df60bvyt85suotrcnwnwfnr2h9dde2,mtnst65vlsvfct6np.cad85 2trbgvtchu1lxrn
#
# --- n = 20899, p = 500000, loss = 2.756700277328491 ---
# b1nytrh sdalmteghdnnehmctcctnnd.stxf5lirvx8thpcslvn5 tkn2cgsrtscu'8 sslvsm7nx n7 scc,nsmdcwud c2tc0n
#
# --- n = 20999, p = 500000, loss = 2.7574682235717773 ---
# eesltltocg ettfc9srondsw stc1.6asflt nyjmr 39cndytp vftdinntw507efc 0mbto,ign ng'nn1nd1trwo nnvnsllg
#
# --- n = 21099, p = 500000, loss = 2.757701873779297 ---
# rnk9th dran7toc1q4tacte1jlxxe'ledyn47e05ytn.nrzco0yfts2lt,vhdv30nmtvn nalvvsorannb2vt4enesebsy6tmbl
#
# --- n = 21199, p = 500000, loss = 2.7577600479125977 ---
# o7n bvnoc1rrdtzehszlg'e3b6ttd52kidtr 7 mh9cfsnpcr32hmcisr efcvtnmtcsccts0p n6gsd7tjutn8rttmcdcntpr d
#
# --- n = 21299, p = 500000, loss = 2.757502794265747 ---
# tys'tqpnoso1eaed 7csrt0n,ro56k93smenintgengtdn ce.rscetc eslzo,ukne1nv. nzlgcvk8bph79ee3cs3g p tt cn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f4a646cd181f> in <module>()
#       7                     global_step = -1)
#       8     training_words = vocab2vec(40, 10 ** 6)
# ----> 9     gru.train(steps = 10**5, training_data = training_words, sample = True, sample_every = 500000, save_per_step = 100000)
#      10 # Used 1 as the standard deviation of the weights
#
# <ipython-input-4-3c509a7b6970> in train(self, steps, training_data, sample, sample_every, save_per_step)
#     136                          self.y: training_data[p+1 : p+1+batch_size]
#     137                          }
# --> 138                 _, next_C, loss = self.sess.run([self.train_step, self.C, self.loss], feed_dict = fdata)
#     139
#     140                 p += batch_size
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Applied drouput layer beore h
if __name__ == "__main__":
    print ("Started!")
    gru = GRU(vocab_size = 40,
                    cell_size = 40,
                    batch_size = 1000,
                    continue_training = False,
                    global_step = -1)
    training_words = vocab2vec(40, 10 ** 6)
    gru.train(steps = 10**5, training_data = training_words, sample = True, sample_every = 500000, save_per_step = 100000)
# Used 1 as the standard deviation of the weights
# Out:
# Started!
# shape is: (992170, 40)
# --- n = 0, p = 500000, loss = 3.7101454734802246 ---
# munk..i.0xx2'ht  hg,jksih9j9 utx2m.motukyhidnn.i.5nkfu9.uperim6'wsozekme2ceouy8tco9jkkmnw89h2xbtjs1.
#
# --- n = 100, p = 500000, loss = 2.804236888885498 ---
# k.4bt4scaeyauxo tdrlutkc5txmtc4ead.t4 sssd7ennfstcwnd ers sj9'zltztsfy6wg2s138ybscc6d.1htc.clp1snqjo
#
# --- n = 200, p = 500000, loss = 2.80615234375 ---
# en7ein 57sn scnh3xcet9 ccv9ssnkzcqohe2c 00 gofedo9. vqg.e8etn8t5gq9n lng6cn wa noo st tnt tvn'vutnn4
#
# --- n = 300, p = 500000, loss = 2.8105077743530273 ---
# 0nsc vrdnldicov8,scts3l.m.ncgsgnss,mez.eccysfseyshlpsjulce bhlv 'stvoetqip0ougnmxedpnnnnjascrgb1kmam
#
# --- n = 400, p = 500000, loss = 2.7862095832824707 ---
# t qrjdpsttgdct 9ut3 0vz4m9gecwotsemmtbtnsbgpd'dnbnsdsl5dsdgn2nc1irsnssnkrovstcnkcujucyuskogjdtctfnqe
#
# --- n = 500, p = 500000, loss = 2.7972395420074463 ---
# nht0iksv0s14casn5lqb2tnncttnfurst'antc16pdl94xnwnxssdsesnwstls2eensocnjcrctwtvetg tbjokttfcocjsplfnk
#
# --- n = 600, p = 500000, loss = 2.8040385246276855 ---
# s9nesc3f2 gzlngsdtlgl4ntdxsvdcqinkpse1oootnacnnc gczg5hzap8cntriswk nlcoujsnsossmn'2c8g tl'xkcd88tvc
#
# --- n = 700, p = 500000, loss = 2.809251070022583 ---
# .538v7cwp ,fcd8msetev1e cutbnerc2s0t9kpysottpynledi rnns svcn5ctn5xwnsc8ts7ot 987kn6r9b2rte2rejkv'8w
#
# --- n = 800, p = 500000, loss = 2.8061776161193848 ---
# xndddcn xh4,mt91gxtgtt5qc'ankcl6ss,dn2fe  cesl1c9l1das.zdmtsncev8724stdtec.cast.vktcon7v,toutsn1ssjc
#
# --- n = 900, p = 500000, loss = 2.801628351211548 ---
# vy  sn9mss5 vltgg.dwsn4tnngsnxrlensfxe6sesyt3f1qpr6ndvrct8lojbgs'5vnnbcl0 dcgct nx6s o5s0jogsstf3dfo
#
# --- n = 1000, p = 500000, loss = 2.8001253604888916 ---
# cncdtcnnys1a21vjttzcsvh catcmt8sklobx4c3ttesfsn6sg2c,tm t5cem nl2tsrjncotstoppnvz lds15ltesggseotone
#
# --- n = 1100, p = 500000, loss = 2.8120274543762207 ---
# i1fvtx.,f6sef7mttyavctwj8dccgncfrkc4vwstvycylos9xzrmsc2tt  6rt6nqpvtn,1c t9stl 85ktorszns7stl2vcvvqt
#
# --- n = 1200, p = 500000, loss = 2.786334991455078 ---
# rw kz u.e7 n. de6mgmihtstrstje9s'mjcdmuwcseco1czqv bbnnmlq84jecost5fn.r8jsedsontqdre3'tsntocdstcnjo
#
# --- n = 1300, p = 500000, loss = 2.815411329269409 ---
# g,cn5 c8q5y6nndsjvtdd6kttfcs7ocm7oxcssanskgteslmrls0yeqfamtctodssi dn7eygv7uns7b0ds5rmnv6oi2ntkr4mrn
#
# --- n = 1400, p = 500000, loss = 2.7837023735046387 ---
# svsot s9dccdqsvjkwocfdrsk3enodt ocrc3e6ddfccgl8,9kox ntaco4ucclo,tgqoclasit,tdyttdz,yftcnsoanws3ttoo
#
# --- n = 1500, p = 500000, loss = 2.8011887073516846 ---
# jnctfol nd36cn,cqeh2usnt1t9qs ge8vrscrrgsledlrbesnatonfeeosnu9ecszitoto avd7os9r7tldtvso ovieteycwmd
#
# --- n = 1600, p = 500000, loss = 2.803079605102539 ---
# dvp8ecz0vc0cenckccasctovc' dn dsk feskgot1epsn.hsmfsr rntnns1dnuns'sdf wmn8otdl tsccktrca6dn 4.m9xwn
#
# --- n = 1700, p = 500000, loss = 2.809420108795166 ---
# v  44.fct7ntn6 p0njspawf tnc.fra5ktnst8qmeq' d,l'oas ycc tsnset,atejw6ex9o,xc1rrssthk2tt9t.s0n7cenrn
#
# --- n = 1800, p = 500000, loss = 2.796600580215454 ---
# m,wo4dddslrt.gnno gu tyslts7gste8'6cexdostssjc1tvduss'j9totpsn8hcyn.aob dne 4v3,jp dze c5vcn6n331s3n
#
# --- n = 1900, p = 500000, loss = 2.8106095790863037 ---
# c t9 sh0jbtcnsn0nn3kptgcgbtbo9 vbsut n3pac25lnc6igttc0enen.h9todxst9cvr156jenc,na ,3p5,   kt'sbb jwn
#
# --- n = 2000, p = 500000, loss = 2.802135705947876 ---
# eneo7ccscml 4n tltkcse6pdn7nt dm6 dn7 sgt5h,ns74sovixt bsmtc2o ndtinvvjcwto'trcin7,len81tdtd1r4d 7.,
#
# --- n = 2100, p = 500000, loss = 2.79569149017334 ---
# fc,fq4anb htdr op.b 'et nlnshlt tgs lddntsdcvgcd8m7zcp004tibettqt5y lladti.ty.cnsc tcsrnlss,.4ssdq6a
#
# --- n = 2200, p = 500000, loss = 2.792107343673706 ---
# l2tlenn'l ks9etdktisevt9.cfl8nscrtvctspecmt il2oosovc wpludnnheoywa9v8ucmn3vbegve3slscv oosamchkncpo
#
# --- n = 2300, p = 500000, loss = 2.803438901901245 ---
# ostsvftalylq8 e ctsetqansfhssc.ltnwijcstcottn'm,nc3 fgdeos,3i60s o1sncl,ofsr,qfdw9n1tn017gkan'nwg7wr
#
# --- n = 2400, p = 500000, loss = 2.7904791831970215 ---
# lsvd9 nnfa4tnsc83tcm ae0nmh st,fibeosnbifmfm76nf'fewsdst8niosmn 1gjldskooc mda2ec0govncmdbojcsrtkwm9
#
# --- n = 2500, p = 500000, loss = 2.8031539916992188 ---
# ntncsnq qsos9atc3ozrunf,xnrgvn6tn'xft82swionetc  qt,gek2vegstetsocgn0tosstkcup  goddttcl8c icn'c8vdl
#
# --- n = 2600, p = 500000, loss = 2.8125665187835693 ---
# ncrgcags.2vfenjss cwoo osstc1 cc'g3n1loo97iscv3k mo1cvj8rswxsd.chq vetvtlss1tpdv50sugrwqeilc' svplcc
#
# --- n = 2700, p = 500000, loss = 2.7876932621002197 ---
# lx5etdtd  ssn4fes3 d'3pqesndtrdvrnnqnstnyn74,sk  ntytntc.tcj757llgslx7t75qgk2t0o5ctn9o,ug,5 cspmn5tl
#
# --- n = 2800, p = 500000, loss = 2.8042185306549072 ---
# ovdtxtssgstln 8nfnh5eelencvdlep,6ti7mkm6tt26n''dw4 zdflmdktcls3qncqxitlobosnejvdttn9streonnaf,t7ttd0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9190868b5451> in <module>()
#       8                     global_step = -1)
#       9     training_words = vocab2vec(40, 10 ** 6)
# ---> 10     gru.train(steps = 10**5, training_data = training_words, sample = True, sample_every = 500000, save_per_step = 100000)
#      11 # Used 1 as the standard deviation of the weights
#
# <ipython-input-7-6a32b0ec1fe8> in train(self, steps, training_data, sample, sample_every, save_per_step)
#     136                          self.y: training_data[p+1 : p+1+batch_size]
#     137                          }
# --> 138                 _, next_C, loss = self.sess.run([self.train_step, self.C, self.loss], feed_dict = fdata)
#     139
#     140                 p += batch_size
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
